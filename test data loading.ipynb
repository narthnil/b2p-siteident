# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt

from src.data_epsg_4326 import BridgeDataset

# %%
ds=BridgeDataset(1200, use_rnd_pos=True)

for _ in range(10):
    i = np.random.choice(len(ds))
    imgs, label = ds[i]
    fig, axes = plt.subplots(1, 5, figsize=(10,10))
    print(imgs[:,:,1:4].shape)
    
    axes[0].imshow(imgs[:, :, 1:4].astype(int))
    axes[0].set_title("OSM Image")
    
    axes[1].imshow(imgs[:, :, 0:1].astype(int), vmin=0, vmax=100, cmap="Purples")
    axes[1].set_title("Population")
    
    axes[2].imshow(imgs[:, :, 4:5].astype(int), cmap="Reds")
    axes[2].set_title("Elevation")
    
    axes[3].imshow(imgs[:, :, 5:6].astype(int), cmap="Blues")
    axes[3].set_title("Slope")
    
    axes[4].imshow(imgs[:, :, 6:].astype(int), cmap="magma")
    axes[4].set_title("admin_boundaries")
    
    # Roadways
    
    # waterways
    
    plt.show()
# Out:
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)
# (48, 48, 3)

# %% [markdown]
# ## Apply transforms

# %%
from src.dataloader_epsg_4326 import BridgeDataset
from torchvision import transforms

# %%
transform = transforms.Compose([
                transforms.Normalize(
                                (59002.390625,
                                 236.64964294433594,
                                 234.1954345703125,
                                 228.14276123046875,
                                 206.40219116210938,
                                 214.48724365234375, 
                                 134.92025756835938),
                                (49175.33203125,
                                 15.285372734069824,
                                 14.796076774597168,
                                 15.021673202514648,
                                 18.009830474853516,
                                 29.860050201416016,
                                 824.8440551757812)
                            )
])

ds=BridgeDataset(1200, use_rnd_pos=True, transform=transform)

# %%
i=np.random.choice(len(ds))
img, label=ds[i]
img.shape
# Out:
# torch.Size([7, 48, 48])

# %%
for _ in range(10):
    i = np.random.choice(len(ds))
    imgs, label = ds[i]
    fig, axes = plt.subplots(1, 5, figsize=(10,10))
    imgs=imgs.permute((1,2,0)).detach().numpy()
    
    axes[0].imshow(imgs[:, :, 1:4].astype(int))
    axes[0].set_title("OSM Image")
    
    axes[1].imshow(imgs[:, :, 0:1].astype(int), vmin=0, vmax=100, cmap="Purples")
    axes[1].set_title("Population")
    
    axes[2].imshow(imgs[:, :, 4:5].astype(int), cmap="Reds")
    axes[2].set_title("Elevation")
    
    axes[3].imshow(imgs[:, :, 5:6].astype(int), cmap="Blues")
    axes[3].set_title("Slope")
    
    axes[4].imshow(imgs[:, :, 6:].astype(int), cmap="magma")
    axes[4].set_title("admin_boundaries")
    
    # Roadways
    
    # waterways
    
    plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
