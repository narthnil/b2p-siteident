# %%
import glob
import json

from os import path

import numpy as np
import pandas as pd
import scipy.stats

# %%
exp_path = "experiments/baselines/*/*"
exps = glob.glob(exp_path)
print("Number of experiments found: {}".format(len(exps)))
finished_exps = [
    exp for exp in exps if len(glob.glob(path.join(exp, "*"))) == 5]
not_finished_exps = [
    exp for exp in exps if len(glob.glob(path.join(exp, "*"))) != 5]
print("Number of experiments finished: {}".format(len(finished_exps)))
print("Unfinished experiments: {}".format(not_finished_exps))
hyperparam_names = sorted([
    "num_classes",
    "num_epochs",
    "use_last_n_layers",
    "no_use_pretrained",
    "lr",
    "model_name", 
    "dataset_name",
    "batch_size"
])
results = {}
agg_results = {}
metrics = [
    # "val_acc", "val_weighted_f1", 
    "test_acc", "test_weighted_f1"]
for exp in finished_exps:
    stat_fpath = path.join(exp, "test_stats.json")
    if not path.isfile(stat_fpath):
        print("{} does not exist.".format(stat_fpath))
        continue
    else:
        with open(stat_fpath) as f:
            stats = json.load(f)
        with open(path.join(exp, "opts.json")) as f:
            opts = json.load(f)
            
        model_opts = tuple([opts[k] for k in hyperparam_names])
        if model_opts not in results:
            results[model_opts] = {k: [] for k in metrics}
        for k in metrics:
            if "f1" in k:
                results[model_opts][k].append(stats[k] * 100)
            else:
                results[model_opts][k].append(stats[k])

for k, stats in results.items():
    if k not in agg_results:
        agg_results[k] = {}
    for name, vals in stats.items():
        agg_results[k][name + "_mean"] = np.round(np.mean(vals), 2)
        agg_results[k][name + "_std"] = np.round(scipy.stats.sem(vals), 2)

header = list(hyperparam_names) + [
    k + pf for k in metrics for pf in ["_mean", "_std"]]

df_rows = []
for k, stats in agg_results.items():
    df_rows.append(list(k))
    for name in metrics:
        df_rows[-1].append(stats[name + "_mean"])
        df_rows[-1].append(stats[name + "_std"])
df = pd.DataFrame(df_rows, columns=header)
# Out:
# Number of experiments found: 540
# Number of experiments finished: 540
# Unfinished experiments: []

# %%
df[
    # (df.model_name == "wide_resnet50_2") &
    (df.no_use_pretrained == False) &
    (df.use_last_n_layers == -1)
].sort_values(by=["dataset_name", "model_name"])
# Out:
#      batch_size                    dataset_name     lr         model_name  \
# 56           64   v1_b2p_rgb_large_1150_600_jpg  0.001  efficientnet_v2_m
# 23           64   v1_b2p_rgb_large_1150_600_jpg  0.001  efficientnet_v2_s
# 94           64   v1_b2p_rgb_large_1150_600_jpg  0.001           resnet18
# 149          64   v1_b2p_rgb_large_1150_600_jpg  0.001           resnet50
# 123          64   v1_b2p_rgb_large_1150_600_jpg  0.001    wide_resnet50_2
# 60           64  v1_b2p_rgb_large_2350_1200_jpg  0.001  efficientnet_v2_m
# 6            64  v1_b2p_rgb_large_2350_1200_jpg  0.001  efficientnet_v2_s
# 77           64  v1_b2p_rgb_large_2350_1200_jpg  0.001           resnet18
# 173          64  v1_b2p_rgb_large_2350_1200_jpg  0.001           resnet50
# 112          64  v1_b2p_rgb_large_2350_1200_jpg  0.001    wide_resnet50_2
# 70           64    v1_b2p_rgb_large_590_320_jpg  0.001  efficientnet_v2_m
# 1            64    v1_b2p_rgb_large_590_320_jpg  0.001  efficientnet_v2_s
# 76           64    v1_b2p_rgb_large_590_320_jpg  0.001           resnet18
# 176          64    v1_b2p_rgb_large_590_320_jpg  0.001           resnet50
# 134          64    v1_b2p_rgb_large_590_320_jpg  0.001    wide_resnet50_2
# 47           64   v2_b2p_rgb_large_1150_600_jpg  0.001  efficientnet_v2_m
# 33           64   v2_b2p_rgb_large_1150_600_jpg  0.001  efficientnet_v2_s
# 98           64   v2_b2p_rgb_large_1150_600_jpg  0.001           resnet18
# 165          64   v2_b2p_rgb_large_1150_600_jpg  0.001           resnet50
# 129          64   v2_b2p_rgb_large_1150_600_jpg  0.001    wide_resnet50_2
# 64           64  v2_b2p_rgb_large_2350_1200_jpg  0.001  efficientnet_v2_m
# 15           64  v2_b2p_rgb_large_2350_1200_jpg  0.001  efficientnet_v2_s
# 82           64  v2_b2p_rgb_large_2350_1200_jpg  0.001           resnet18
# 164          64  v2_b2p_rgb_large_2350_1200_jpg  0.001           resnet50
# 124          64  v2_b2p_rgb_large_2350_1200_jpg  0.001    wide_resnet50_2
# 40           64    v2_b2p_rgb_large_590_320_jpg  0.001  efficientnet_v2_m
# 26           64    v2_b2p_rgb_large_590_320_jpg  0.001  efficientnet_v2_s
# 74           64    v2_b2p_rgb_large_590_320_jpg  0.001           resnet18
# 155          64    v2_b2p_rgb_large_590_320_jpg  0.001           resnet50
# 142          64    v2_b2p_rgb_large_590_320_jpg  0.001    wide_resnet50_2
#
#      no_use_pretrained  num_classes  num_epochs  use_last_n_layers  \
# 56               False            2         200                 -1
# 23               False            2         200                 -1
# 94               False            2         200                 -1
# 149              False            2         200                 -1
# 123              False            2         200                 -1
# 60               False            2         200                 -1
# 6                False            2         200                 -1
# 77               False            2         200                 -1
# 173              False            2         200                 -1
# 112              False            2         200                 -1
# 70               False            2         200                 -1
# 1                False            2         200                 -1
# 76               False            2         200                 -1
# 176              False            2         200                 -1
# 134              False            2         200                 -1
# 47               False            2         200                 -1
# 33               False            2         200                 -1
# 98               False            2         200                 -1
# 165              False            2         200                 -1
# 129              False            2         200                 -1
# 64               False            2         200                 -1
# 15               False            2         200                 -1
# 82               False            2         200                 -1
# 164              False            2         200                 -1
# 124              False            2         200                 -1
# 40               False            2         200                 -1
# 26               False            2         200                 -1
# 74               False            2         200                 -1
# 155              False            2         200                 -1
# 142              False            2         200                 -1
#
#      test_acc_mean  test_acc_std  test_weighted_f1_mean  test_weighted_f1_std
# 56           61.02          0.86                  60.19                  1.26
# 23           61.32          1.23                  60.61                  1.68
# 94           63.33          0.89                  62.97                  1.00
# 149          65.16          0.28                  65.01                  0.29
# 123          60.22          1.46                  60.12                  1.43
# 60           54.95          1.65                  54.61                  1.79
# 6            59.30          1.68                  58.67                  1.48
# 77           58.25          1.61                  57.91                  1.56
# 173          57.39          1.49                  57.06                  1.51
# 112          52.53          0.94                  52.15                  1.29
# 70           59.44          1.51                  58.22                  1.79
# 1            61.72          0.05                  61.35                  0.27
# 76           61.72          1.22                  61.41                  1.34
# 176          65.43          0.43                  65.27                  0.29
# 134          60.94          2.67                  60.80                  2.60
# 47           61.37          0.52                  61.09                  0.56
# 33           63.10          1.25                  62.75                  1.33
# 98           62.33          1.68                  62.13                  1.60
# 165          63.40          0.39                  63.06                  0.27
# 129          62.75          1.32                  62.61                  1.39
# 64           58.10          0.39                  57.79                  0.32
# 15           56.87          1.29                  56.41                  1.51
# 82           59.10          1.35                  58.85                  1.42
# 164          58.91          1.76                  58.57                  1.86
# 124          56.07          0.39                  55.93                  0.35
# 40           63.48          0.47                  62.89                  0.61
# 26           61.83          0.47                  61.58                  0.33
# 74           63.63          1.47                  63.22                  1.57
# 155          64.48          1.30                  64.19                  1.40
# 142          61.14          1.67                  60.80                  1.44

# %%
df[df.model_name == "wide_resnet50_2"].groupby([
    "dataset_name", 
    "lr", 
    "no_use_pretrained", 
    "num_classes",
    "num_epochs",
    "batch_size",
    "use_last_n_layers",
    "model_name"
]).max("val_acc_mean")
# Out:
#                                                                                                                             val_acc_mean  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2         59.02
#                                                                                          9                 wide_resnet50_2         59.44
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2         56.13
#                                                                                          9                 wide_resnet50_2         61.02
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2         59.30
#                                                                                          9                 wide_resnet50_2         59.02
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2         58.88
#                                                                                          9                 wide_resnet50_2         61.11
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2         61.56
#                                                                                          9                 wide_resnet50_2         62.64
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2         58.81
#                                                                                          9                 wide_resnet50_2         59.71
#
#                                                                                                                             val_acc_std  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2         0.42
#                                                                                          9                 wide_resnet50_2         0.70
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2         0.68
#                                                                                          9                 wide_resnet50_2         0.93
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2         0.61
#                                                                                          9                 wide_resnet50_2         0.35
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2         0.74
#                                                                                          9                 wide_resnet50_2         0.68
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2         0.86
#                                                                                          9                 wide_resnet50_2         0.54
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2         0.41
#                                                                                          9                 wide_resnet50_2         0.33
#
#                                                                                                                             val_weighted_f1_mean  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                 56.40
#                                                                                          9                 wide_resnet50_2                 56.50
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                 52.61
#                                                                                          9                 wide_resnet50_2                 58.79
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                 58.09
#                                                                                          9                 wide_resnet50_2                 56.09
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                 56.97
#                                                                                          9                 wide_resnet50_2                 59.62
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                 59.98
#                                                                                          9                 wide_resnet50_2                 60.63
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                 57.63
#                                                                                          9                 wide_resnet50_2                 57.31
#
#                                                                                                                             val_weighted_f1_std  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                 1.26
#                                                                                          9                 wide_resnet50_2                 0.60
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                 2.11
#                                                                                          9                 wide_resnet50_2                 1.32
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                 0.82
#                                                                                          9                 wide_resnet50_2                 0.26
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                 0.66
#                                                                                          9                 wide_resnet50_2                 0.92
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                 1.80
#                                                                                          9                 wide_resnet50_2                 0.80
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                 0.60
#                                                                                          9                 wide_resnet50_2                 0.16
#
#                                                                                                                             test_acc_mean  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2          54.03
#                                                                                          9                 wide_resnet50_2          55.97
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2          51.75
#                                                                                          9                 wide_resnet50_2          54.41
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2          52.66
#                                                                                          9                 wide_resnet50_2          52.45
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2          52.42
#                                                                                          9                 wide_resnet50_2          53.73
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2          51.80
#                                                                                          9                 wide_resnet50_2          52.19
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2          54.45
#                                                                                          9                 wide_resnet50_2          54.03
#
#                                                                                                                             test_acc_std  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2          0.29
#                                                                                          9                 wide_resnet50_2          0.24
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2          1.53
#                                                                                          9                 wide_resnet50_2          0.53
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2          0.41
#                                                                                          9                 wide_resnet50_2          1.05
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2          0.62
#                                                                                          9                 wide_resnet50_2          0.33
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2          0.36
#                                                                                          9                 wide_resnet50_2          1.73
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2          0.80
#                                                                                          9                 wide_resnet50_2          0.28
#
#                                                                                                                             test_weighted_f1_mean  \
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                  52.41
#                                                                                          9                 wide_resnet50_2                  53.72
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                  49.62
#                                                                                          9                 wide_resnet50_2                  51.62
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                  51.17
#                                                                                          9                 wide_resnet50_2                  49.42
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                  49.83
#                                                                                          9                 wide_resnet50_2                  51.72
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                  50.30
#                                                                                          9                 wide_resnet50_2                  50.53
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                  53.40
#                                                                                          9                 wide_resnet50_2                  52.14
#
#                                                                                                                             test_weighted_f1_std
# dataset_name                   lr    no_use_pretrained num_classes num_epochs batch_size use_last_n_layers model_name
# v1_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                  0.68
#                                                                                          9                 wide_resnet50_2                  0.71
# v1_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                  1.59
#                                                                                          9                 wide_resnet50_2                  0.18
# v1_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                  0.52
#                                                                                          9                 wide_resnet50_2                  0.56
# v2_b2p_rgb_large_1150_600_jpg  0.001 False             2           200        64         1                 wide_resnet50_2                  0.60
#                                                                                          9                 wide_resnet50_2                  0.31
# v2_b2p_rgb_large_2350_1200_jpg 0.001 False             2           200        64         1                 wide_resnet50_2                  0.97
#                                                                                          9                 wide_resnet50_2                  1.30
# v2_b2p_rgb_large_590_320_jpg   0.001 False             2           200        64         1                 wide_resnet50_2                  1.11
#                                                                                          9                 wide_resnet50_2                  0.15
