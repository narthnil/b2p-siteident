# %%
import functools
import glob
import math
import json
import os
import time

from os import path

import ee
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from multiprocessing import Pool
from geographiclib.geodesic import Geodesic
from geopy.geocoders import Nominatim
from tqdm import notebook as tqdm
from collections import Counter
import rasterio
from shapely.geometry import Point, Polygon

from typing import List, Tuple
import geopandas as gpd

# %% [markdown]
# # Modules

# %%
def sample_points_in_polygon(polygon: Polygon,
                             num_samples: float = 1,
                             add_padding=False) -> List[Tuple]:
    """Sample point(s) within a given polygon.

    This function `num_samples` samples points that lies within the bounds of a
    given polygon. First, a point is uniformly sampled that are within the
    minimum and maximum latitude and longitude of the polygon. Then the point
    is checked whether it is within the polygon. These two steps are repeated
    until there are `num_samples` points that are returned.

    Args:
        polygon (Polygon): A polygon that containts all points that are
            randomly sampled.
        num_samples (float)

    Returns:
        points (List[Tuple]): A list of points. The points are representated
            as tuples of x (longitude) and y (latitude) values.
    """
    points = []
    # get boundaries (minimum and maximum latitude and longitude) of polygon
    min_x, min_y, max_x, max_y = polygon.bounds
    if add_padding:
        min_x += 1 / 180
        min_y += 1 / 180
        max_x -= 1 / 180
        max_y -= 1 / 180

    # repeat sampling process while the number of points samples is not equal
    # `num_samples`
    while len(points) < num_samples:
        # uniformly sample longitude (x) and latitude with bounds
        x, y = np.random.uniform(
            min_x, max_x), np.random.uniform(min_y, max_y)
        point = Point(x, y)
        # if point is within the polygon, add it to list `points`
        if polygon.contains(point):
            points.append((x, y))
    return points

# %%
def get_square_area(longitude: float, latitude: float,
                    square_length: float = 200.,
                    geod: Geodesic = None):
    """
    Args:
        lat: Latitude
        lon: Longtitude
        square_length: Measured in meters.
        geod: (Geodesic)
    Returns:
        square_pts: [lower left x, lower left y, ...
                     upper right x, upper right y]
    """
    if geod is None:
        #Define the ellipsoid
        geod = Geodesic.WGS84
    diag_len = np.sqrt(2*(square_length / 2.)**2)
    ll_point = geod.Direct(latitude, longitude, -135, diag_len)
    ur_point = geod.Direct(latitude, longitude, 45, diag_len)
    square_pts = [
        ll_point['lon2'], ll_point['lat2'],  # min x, min y
        ur_point['lon2'], ur_point['lat2']   # max x, max y
    ]
    return square_pts

# %%
# Function to mask clouds using the Sentinel-2 QA band
# @param {ee.Image} image Sentinel-2 image
# @return {ee.Image} cloud masked Sentinel-2 image

def mask2clouds(image):
    qa = image.select('QA60');
    # Bits 10 and 11 are clouds and cirrus, respectively.
    cloudBitMask = 1 << 10;
    cirrusBitMask = 1 << 11;

    # Both flags should be set to zero, indicating clear conditions.
    mask = qa.bitwiseAnd(cloudBitMask).eq(0) and qa.bitwiseAnd(cirrusBitMask).eq(0)

    return image.updateMask(mask).divide(10000)

# %% [markdown]
# # Authenticate

# %%
# Trigger the authentication flow.
ee.Authenticate()

# Initialize the library.
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=vWH2yQC9bONaqHuZy3KC6azjptwdmy_ZPVXbaWzgIGM&tc=-er9OkFuYLr3OKU0x1XUeGYTeSQ1F-hK1CRrUwy46hs&cc=x27Q4KTifnpbhwegAiuxeptmFezYBwzC1T9ULsUWuys>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=vWH2yQC9bONaqHuZy3KC6azjptwdmy_ZPVXbaWzgIGM&tc=-er9OkFuYLr3OKU0x1XUeGYTeSQ1F-hK1CRrUwy46hs&cc=x27Q4KTifnpbhwegAiuxeptmFezYBwzC1T9ULsUWuys</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AdQt8qjTHpop8sYGGxdXEZx5L21uMDqua9ropbzmZoW45CyI59poLkfpRgY
#
# Successfully saved authorization token.

# %% [markdown]
# # Load dataset

# %%
# Map the function over one year of data and take the median.
# Load Sentinel-2 TOA reflectance data.
dataset = ee.ImageCollection('COPERNICUS/S2')
dataset = dataset.filterDate('2017-01-01', '2021-07-01')
# Pre-filter to get less cloudy granules.
dataset = dataset.filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 5)) 
dataset = dataset.map(mask2clouds)
dataset = dataset.median()

# %%
# RGB visualization configuration
rgbVis = {
  "min": 0.0,
  "max": 0.3,
  "bands": ['B4', 'B3', 'B2']
}

# %% [markdown]
# # Load metadata

# %%
with open("../data/ground_truth/train_1200_v2.geojson") as f:
    v2 = gpd.read_file(f)
    vgdf = v2
    vname = "v2"

lon_lat_list = []

num_tr = len(vgdf[(vgdf.split == "train") & (vgdf.pos_neg == "pos")])
num_tr_low = len(vgdf[(vgdf.split == "train_lower") & (vgdf.pos_neg == "pos")])
num_tr_upp = len(vgdf[(vgdf.split == "train_upper") & (vgdf.pos_neg == "pos")])

num_va = len(vgdf[(vgdf.split.str.startswith("val") & (vgdf.pos_neg == "pos"))])
num_te_rw = len(vgdf[vgdf.split.str.startswith("test") & (vgdf.pos_neg == "pos") & (vgdf.Country == "Rwanda")])
num_te_ug = len(vgdf[vgdf.split.str.startswith("test") & (vgdf.pos_neg == "pos") & (vgdf.Country == "Uganda")])

ind = vgdf[(vgdf.split == "train-lower") & (vgdf.pos_neg == "neg")].index[0]
samples = sample_points_in_polygon(vgdf.iloc[ind].geometry, num_tr_low)
samples = [
    (s[0], s[1], vgdf.iloc[ind].id + "-{}".format(i)) 
    for i, s in enumerate(samples)]
lon_lat_list += samples

ind = vgdf[(vgdf.split == "train-upper") & (vgdf.pos_neg == "neg")].index[0]
samples = sample_points_in_polygon(vgdf.iloc[ind].geometry, num_tr_upp)
samples = [
    (s[0], s[1], vgdf.iloc[ind].id + "-{}".format(i)) 
    for i, s in enumerate(samples)]
lon_lat_list += samples

ind = vgdf[(vgdf.split == "train") & (vgdf.pos_neg == "neg")].index[0]
samples = sample_points_in_polygon(vgdf.iloc[ind].geometry, num_tr_upp)
samples = [
    (s[0], s[1], vgdf.iloc[ind].id + "-{}".format(i)) 
    for i, s in enumerate(samples)]
lon_lat_list += samples

ind = vgdf[(vgdf.split == "val") & (vgdf.pos_neg == "neg")].index[0]
samples = sample_points_in_polygon(vgdf.iloc[ind].geometry, num_va)
samples = [
    (s[0], s[1], vgdf.iloc[ind].id + "-{}".format(i)) 
    for i, s in enumerate(samples)]
lon_lat_list += samples

ind = vgdf[(vgdf.split == "test") & (vgdf.pos_neg == "neg") & (vgdf.Country == "Uganda")].index[0]
samples = sample_points_in_polygon(vgdf.iloc[ind].geometry, num_te_ug)
samples = [
    (s[0], s[1], vgdf.iloc[ind].id + "-{}".format(i)) 
    for i, s in enumerate(samples)]
lon_lat_list += samples

ind = vgdf[(vgdf.split == "test") & (vgdf.pos_neg == "neg") & (vgdf.Country == "Rwanda")].index[0]
samples = sample_points_in_polygon(vgdf.iloc[ind].geometry, num_te_rw)
samples = [
    (s[0], s[1], vgdf.iloc[ind].id + "-{}".format(i)) 
    for i, s in enumerate(samples)]
lon_lat_list += samples

lon_lat_list = sorted(lon_lat_list)

# %%
len(lon_lat_list)
# Out:
# 1719

# %% [markdown]
# # Check data

# %%
folders = {
    320: "v1_b2p_rgb/v1_b2p_rgb_large_590_320",
    600: "v1_b2p_rgb/v1_b2p_rgb_large_1150_600",
    1200: "v1_b2p_rgb/v1_b2p_rgb_large_2350_1200"
}

# %%
v1[v1.id.str.contains("006f100000a86Fk")]
# Out:
#                     id  GPS (Latitude)  GPS (Longitude)        split  \
# 99  rw-006f100000a86Fk       -2.280762        29.206295  train_lower
#
#         min_x      max_x Country pos_neg  \
# 99  28.854443  29.595857  Rwanda     pos
#
#                                              geometry
# 99  POLYGON ((29.21146 -2.28596, 29.20113 -2.28596...

# %%
for tile_size in [320, 600, 1200]:
    folder = folders[tile_size]
    tif_files = glob.glob(path.join(folder, "*.tif"))
    print("Tile size: {}".format(tile_size))
    print("No. of tif files: {}, no. lat lon samples {}".format(
        len(tif_files), len(lon_lat_list)))
    area_length = 2 * tile_size - 50
    for n in range(len(lon_lat_list)):
        prefix = "{}m_{}".format(area_length, lon_lat_list[n][2])
        files = glob.glob(path.join(folder, prefix) + ".tif") + glob.glob(
            path.join(folder, prefix) + "(1).tif")
        if len(files) < 0:
            print("[WARM] {} does not exist".format(prefix))
        elif len(files) > 1:
            print("[WARM] {} has more than 1 file.".format(prefix))
            print(files)
    break
# Out:
# Tile size: 320
# No. of tif files: 3354, no. lat lon samples 3354
# [WARM] 590m_train_pos_rw-006f100000a86Fx has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fx.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fx(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Fk has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fk.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fk(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Fu has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fu.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fu(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Ft has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ft.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ft(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Fr has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fr.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fr(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Dq has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Dq.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Dq(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86HI has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86HI.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86HI(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FA has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FA.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FA(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FI has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FI.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FI(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FC has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FC.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FC(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gk has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gk.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gk(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gg has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gg.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gg(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Go has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Go.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Go(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FH has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FH.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FH(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gc has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gc.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gc(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Dp has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Dp.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Dp(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GF has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GF.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GF(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Ga has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ga.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ga(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GN has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GN.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GN(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GM has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GM.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GM(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gi has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gi.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gi(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gw has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gw.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gw(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GC has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GC.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GC(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GI has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GI.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GI(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GO has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GO.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GO(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FU has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FU.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FU(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GL has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GL.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GL(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GA has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GA.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GA(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GB has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GB.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GB(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Eq has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Eq.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Eq(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GX has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GX.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GX(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Eo has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Eo.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Eo(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Eg has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Eg.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Eg(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gb has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gb.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gb(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gt has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gt.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gt(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gr has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gr.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gr(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gn has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gn.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gn(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86ET has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86ET.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86ET(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Er has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Er.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Er(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Ep has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ep.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ep(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86En has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86En.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86En(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Ds has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ds.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ds(1).tif']
# [WARM] 590m_train_pos_rw-006f100000d7JDW has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7JDW.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7JDW(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FT has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FT.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FT(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GD has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GD.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GD(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FB has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FB.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FB(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gd has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gd.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gd(1).tif']
# [WARM] 590m_train_pos_rw-006f100000d7JCT has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7JCT.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7JCT(1).tif']
# [WARM] 590m_train_pos_rw-006f100000d7JCY has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7JCY.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7JCY(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FJ has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FJ.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FJ(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Fb has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fb.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fb(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FR has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FR.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FR(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Ef has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ef.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ef(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Fc has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fc.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fc(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GW has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GW.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GW(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gm has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gm.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gm(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FY has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FY.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FY(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FK has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FK.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FK(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Gy has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gy.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Gy(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FX has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FX.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FX(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Fj has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fj.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Fj(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86ER has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86ER.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86ER(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86FZ has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FZ.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86FZ(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GR has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GR.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GR(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86GG has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GG.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86GG(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Et has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Et.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Et(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Ew has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ew.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Ew(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86EF has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86EF.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86EF(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86EG has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86EG.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86EG(1).tif']
# [WARM] 590m_train_pos_rw-006f100000d7jDw has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7jDw.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7jDw(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Du has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Du.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Du(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86Dw has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Dw.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86Dw(1).tif']
# [WARM] 590m_train_pos_rw-006f100000d7jCy has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7jCy.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7jCy(1).tif']
# [WARM] 590m_train_pos_rw-006f100000d7jCt has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7jCt.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000d7jCt(1).tif']
# [WARM] 590m_train_pos_rw-006f100000a86HK has more than 1 file.
# ['v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86HK.tif', 'v1_b2p_rgb/v1_b2p_rgb_large_590_320/590m_train_pos_rw-006f100000a86HK(1).tif']

# %%
len(unique_lonlat_names), len(unique_fnames)
# Out:
# (3354, 3354)

# %%
unique_lonlat_names.difference(unique_fnames)
# Out:
# {'590m_test_pos_rw-006f100000bMK0j',
#  '590m_test_pos_rw-006f100000d7kjZ',
#  '590m_test_pos_rw-006f100000d7bAM',
#  '590m_val_pos_rw-006f100000a86Fz',
#  '590m_rw-neg-te-0-133',
#  '590m_test_pos_rw-006f100000d7kmY',
#  '590m_rw-neg-te-0-425',
#  '590m_rw-neg-te-0-341',
#  '590m_test_pos_rw-006f100000bMJys',
#  '590m_test_pos_rw-006f100000ZQRpz',
#  '590m_rw-neg-te-0-619',
#  '590m_val_pos_rw-006f100000d7EVd',
#  '590m_test_pos_rw-006f100000eeqs4',
#  '590m_rw-neg-te-0-503',
#  '590m_val_pos_rw-006f100000a86DB',
#  '590m_rw-neg-te-0-465',
#  '590m_rw-neg-te-0-567',
#  '590m_rw-neg-te-0-592',
#  '590m_rw-neg-te-0-569',
#  '590m_test_pos_rw-006f100000eekYU',
#  '590m_rw-neg-te-0-316',
#  '590m_rw-neg-te-0-598',
#  '590m_rw-neg-te-0-46',
#  '590m_test_pos_rw-006f100000d7jID',
#  '590m_test_pos_rw-006f100000biKAu',
#  '590m_rw-neg-te-0-129',
#  '590m_rw-neg-te-0-538',
#  '590m_rw-neg-te-0-210',
#  '590m_val_pos_rw-006f100000d7Q9N',
#  '590m_test_pos_rw-006f100000eessF',
#  '590m_val_pos_rw-006f100000d6wCD',
#  '590m_val_pos_rw-006f100000d7ELo',
#  '590m_rw-neg-te-0-291',
#  '590m_rw-neg-te-0-55',
#  '590m_rw-neg-te-0-367',
#  '590m_rw-neg-te-0-264',
#  '590m_test_pos_rw-006f100000d7EQ9',
#  '590m_rw-neg-te-0-81',
#  '590m_rw-neg-te-0-354',
#  '590m_val_pos_rw-006f100000d7QTX',
#  '590m_test_pos_rw-006f100000d75zj',
#  '590m_val_pos_rw-006f100000d7PqS',
#  '590m_val_pos_rw-006f100000d7629',
#  '590m_rw-neg-te-0-488',
#  '590m_rw-neg-te-0-466',
#  '590m_rw-neg-te-0-23',
#  '590m_rw-neg-te-0-492',
#  '590m_test_pos_rw-006f100000ef7eO',
#  '590m_test_pos_rw-006f100000efEem',
#  '590m_val_pos_rw-006f100000d7ETc',
#  '590m_test_pos_rw-006f100000d7jI3',
#  '590m_rw-neg-te-0-242',
#  '590m_val_pos_rw-006f100000a86Cx',
#  '590m_test_pos_rw-006f100000a86DM',
#  '590m_rw-neg-te-0-156',
#  '590m_val_pos_rw-006f100000atGB5',
#  '590m_rw-neg-te-0-431',
#  '590m_rw-neg-te-0-1',
#  '590m_rw-neg-te-0-306',
#  '590m_val_pos_rw-006f100000d7JCi',
#  '590m_test_pos_rw-006f100000a7n8N',
#  '590m_rw-neg-te-0-95',
#  '590m_test_pos_rw-006f100000eeuzs',
#  '590m_val_pos_rw-006f100000a86HN',
#  '590m_val_pos_rw-006f100000a86Gf',
#  '590m_rw-neg-te-0-58',
#  '590m_rw-neg-te-0-580',
#  '590m_test_pos_rw-006f100000a86G7',
#  '590m_rw-neg-te-0-379',
#  '590m_rw-neg-te-0-334',
#  '590m_rw-neg-te-0-162',
#  '590m_rw-neg-te-0-142',
#  '590m_rw-neg-te-0-615',
#  '590m_test_pos_rw-006f100000dhpEh',
#  '590m_val_pos_rw-006f100000d7Q9I',
#  '590m_rw-neg-te-0-506',
#  '590m_rw-neg-te-0-563',
#  '590m_val_pos_rw-006f100000d7Q5l',
#  '590m_test_pos_rw-006f100000eesdK',
#  '590m_val_pos_rw-006f100000a86Gu',
#  '590m_val_pos_rw-006f100000a86D2',
#  '590m_rw-neg-te-0-98',
#  '590m_rw-neg-te-0-357',
#  '590m_test_pos_rw-006f100000d7Q9m',
#  '590m_test_pos_rw-006f100000a86Hi',
#  '590m_rw-neg-te-0-350',
#  '590m_rw-neg-te-0-366',
#  '590m_test_pos_rw-006f100000eekgC',
#  '590m_val_pos_rw-006f100000d78OB',
#  '590m_rw-neg-te-0-265',
#  '590m_rw-neg-te-0-416',
#  '590m_test_pos_rw-006f100000a86HU',
#  '590m_rw-neg-te-0-450',
#  '590m_rw-neg-te-0-74',
#  '590m_rw-neg-te-0-87',
#  '590m_rw-neg-te-0-561',
#  '590m_val_pos_rw-006f100000a86G3',
#  '590m_rw-neg-te-0-370',
#  '590m_rw-neg-te-0-464',
#  '590m_rw-neg-te-0-294',
#  '590m_rw-neg-te-0-105',
#  '590m_val_pos_rw-006f100000d7Q65',
#  '590m_test_pos_rw-006f100000d7ibY',
#  '590m_rw-neg-te-0-391',
#  '590m_rw-neg-te-0-106',
#  '590m_test_pos_rw-006f100000d7jIN',
#  '590m_test_pos_rw-006f100000eelvw',
#  '590m_test_pos_rw-006f100000d6kpD',
#  '590m_rw-neg-te-0-507',
#  '590m_rw-neg-te-0-484',
#  '590m_test_pos_rw-006f100000efHAR',
#  '590m_val_pos_rw-006f100000d6mYL',
#  '590m_test_pos_rw-006f100000d7icR',
#  '590m_rw-neg-te-0-559',
#  '590m_val_pos_rw-006f100000bh0EZ',
#  '590m_val_pos_rw-006f100000a86Dy',
#  '590m_rw-neg-te-0-352',
#  '590m_rw-neg-te-0-523',
#  '590m_val_pos_rw-006f100000d7JCn',
#  '590m_val_pos_rw-006f100000d6mY6',
#  '590m_rw-neg-te-0-613',
#  '590m_val_pos_rw-006f100000d7Q5M',
#  '590m_rw-neg-te-0-423',
#  '590m_rw-neg-te-0-226',
#  '590m_rw-neg-te-0-595',
#  '590m_test_pos_rw-006f100000c5V2g',
#  '590m_test_pos_rw-006f100000a86DS',
#  '590m_test_pos_rw-006f100000d7jIS',
#  '590m_rw-neg-te-0-53',
#  '590m_rw-neg-te-0-419',
#  '590m_test_pos_rw-006f100000d766e',
#  '590m_test_pos_rw-006f100000eesdP',
#  '590m_test_pos_rw-006f100000d760h',
#  '590m_rw-neg-te-0-588',
#  '590m_test_pos_rw-006f100000eekdD',
#  '590m_val_pos_rw-006f100000d6wQw',
#  '590m_rw-neg-te-0-467',
#  '590m_rw-neg-te-0-88',
#  '590m_val_pos_rw-006f100000d6wBo',
#  '590m_rw-neg-te-0-121',
#  '590m_rw-neg-te-0-128',
#  '590m_val_pos_rw-006f100000d762O',
#  '590m_rw-neg-te-0-500',
#  '590m_rw-neg-te-0-442',
#  '590m_val_pos_rw-006f100000d7EVn',
#  '590m_rw-neg-te-0-144',
#  '590m_rw-neg-te-0-32',
#  '590m_val_pos_rw-006f100000a86Fi',
#  '590m_rw-neg-val-0-234',
#  '590m_rw-neg-te-0-238',
#  '590m_test_pos_rw-006f100000ZQRq3',
#  '590m_rw-neg-te-0-476',
#  '590m_val_pos_rw-006f100000d7QQY',
#  '590m_test_pos_rw-006f100000c5V35',
#  '590m_test_pos_rw-006f100000a86I3',
#  '590m_val_pos_rw-006f100000a86EO',
#  '590m_test_pos_rw-006f100000d75ze',
#  '590m_val_pos_rw-006f100000d7624',
#  '590m_test_pos_rw-006f100000dhpDe',
#  '590m_test_pos_rw-006f100000eesse',
#  '590m_test_pos_rw-006f100000c5iL7',
#  '590m_val_pos_rw-006f100000d6wRQ',
#  '590m_rw-neg-te-0-285',
#  '590m_rw-neg-te-0-248',
#  '590m_rw-neg-te-0-487',
#  '590m_rw-neg-te-0-393',
#  '590m_rw-neg-te-0-460',
#  '590m_rw-neg-te-0-152',
#  '590m_rw-neg-te-0-30',
#  '590m_test_pos_rw-006f100000eekV1',
#  '590m_rw-neg-te-0-480',
#  '590m_test_pos_rw-006f100000d7EPz',
#  '590m_rw-neg-te-0-233',
#  '590m_val_pos_rw-006f100000d7hE8',
#  '590m_rw-neg-te-0-44',
#  '590m_val_pos_rw-006f100000d7x5j',
#  '590m_val_pos_rw-006f100000d7ieS',
#  '590m_test_pos_rw-006f100000d6wFb',
#  '590m_test_pos_rw-006f100000eekg2',
#  '590m_rw-neg-te-0-143',
#  '590m_test_pos_rw-006f100000ZQRkP',
#  '590m_val_pos_rw-006f100000a86Dx',
#  '590m_rw-neg-te-0-539',
#  '590m_rw-neg-te-0-283',
#  '590m_val_pos_rw-006f100000d7wve',
#  '590m_test_pos_rw-006f100000biKAf',
#  '590m_rw-neg-te-0-9',
#  '590m_val_pos_rw-006f100000d7Pqw',
#  '590m_val_pos_rw-006f100000d7if6',
#  '590m_rw-neg-te-0-362',
#  '590m_val_pos_rw-006f100000d6ksK',
#  '590m_test_pos_rw-006f100000d7ESZ',
#  '590m_val_pos_rw-006f100000dhpCg',
#  '590m_test_pos_rw-006f100000eesiZ',
#  '590m_val_pos_rw-006f100000ZQRq9',
#  '590m_rw-neg-te-0-218',
#  '590m_test_pos_rw-006f100000eekX2',
#  '590m_rw-neg-te-0-445',
#  '590m_test_pos_rw-006f100000a86Hp',
#  '590m_rw-neg-te-0-188',
#  '590m_test_pos_rw-006f100000d767D',
#  '590m_val_pos_rw-006f100000d7QSt',
#  '590m_rw-neg-te-0-160',
#  '590m_rw-neg-te-0-2',
#  '590m_rw-neg-te-0-489',
#  '590m_test_pos_rw-006f100000eekh0',
#  '590m_val_pos_rw-006f100000d761u',
#  '590m_val_pos_rw-006f100000a86EX',
#  '590m_rw-neg-te-0-261',
#  '590m_rw-neg-te-0-118',
#  '590m_rw-neg-te-0-48',
#  '590m_val_pos_rw-006f100000d761z',
#  '590m_rw-neg-te-0-373',
#  '590m_val_pos_rw-006f100000a86EQ',
#  '590m_test_pos_rw-006f100000eewEc',
#  '590m_test_pos_rw-006f100000d7ERl',
#  '590m_rw-neg-te-0-591',
#  '590m_rw-neg-te-0-383',
#  '590m_rw-neg-te-0-311',
#  '590m_val_pos_rw-006f100000d7ieX',
#  '590m_rw-neg-te-0-440',
#  '590m_rw-neg-te-0-337',
#  '590m_rw-neg-te-0-600',
#  '590m_test_pos_rw-006f100000d760m',
#  '590m_rw-neg-te-0-221',
#  '590m_rw-neg-te-0-110',
#  '590m_rw-neg-te-0-277',
#  '590m_val_pos_rw-006f100000d7jHF',
#  '590m_test_pos_rw-006f100000d6ksP',
#  '590m_rw-neg-te-0-251',
#  '590m_test_pos_rw-006f100000d7jHP',
#  '590m_rw-neg-te-0-103',
#  '590m_test_pos_rw-006f100000a86He',
#  '590m_rw-neg-te-0-304',
#  '590m_rw-neg-te-0-382',
#  '590m_rw-neg-te-0-45',
#  '590m_rw-neg-te-0-395',
#  '590m_test_pos_rw-006f100000biK9w',
#  '590m_rw-neg-te-0-347',
#  '590m_rw-neg-te-0-259',
#  '590m_rw-neg-te-0-198',
#  '590m_rw-neg-te-0-127',
#  '590m_rw-neg-te-0-599',
#  '590m_rw-neg-te-0-179',
#  '590m_rw-neg-te-0-517',
#  '590m_test_pos_rw-006f100000eekYF',
#  '590m_rw-neg-te-0-173',
#  '590m_rw-neg-te-0-250',
#  '590m_rw-neg-te-0-300',
#  '590m_rw-neg-te-0-175',
#  '590m_rw-neg-te-0-49',
#  '590m_test_pos_rw-006f100000bMK1d',
#  '590m_test_pos_rw-006f100000d760r',
#  '590m_rw-neg-te-0-560',
#  '590m_test_pos_rw-006f100000ZQRpv',
#  '590m_rw-neg-te-0-434',
#  '590m_rw-neg-te-0-481',
#  '590m_test_pos_rw-006f100000d7jII',
#  '590m_test_pos_rw-006f100000d766t',
#  '590m_test_pos_rw-006f100000d7673',
#  '590m_rw-neg-te-0-19',
#  '590m_rw-neg-te-0-533',
#  '590m_test_pos_rw-006f100000d7603',
#  '590m_test_pos_rw-006f100000eekhF',
#  '590m_val_pos_rw-006f100000a86EM',
#  '590m_test_pos_rw-006f100000d75zo',
#  '590m_rw-neg-te-0-64',
#  '590m_rw-neg-te-0-392',
#  '590m_val_pos_rw-006f100000d6wBt',
#  '590m_val_pos_rw-006f100000a86E0',
#  '590m_rw-neg-te-0-13',
#  '590m_rw-neg-te-0-339',
#  '590m_test_pos_rw-006f100000eescq',
#  '590m_test_pos_rw-006f100000a86Hz',
#  '590m_rw-neg-te-0-498',
#  '590m_rw-neg-te-0-542',
#  '590m_test_pos_rw-006f100000biKAL',
#  '590m_val_pos_rw-006f100000d7EMI',
#  '590m_rw-neg-te-0-309',
#  '590m_rw-neg-te-0-473',
#  '590m_val_pos_rw-006f100000a86EW',
#  '590m_test_pos_rw-006f100000a86I0',
#  '590m_rw-neg-te-0-21',
#  '590m_rw-neg-te-0-241',
#  '590m_val_pos_rw-006f100000Zt6Uj',
#  '590m_val_pos_rw-006f100000d7wug',
#  '590m_rw-neg-te-0-365',
#  '590m_test_pos_rw-006f100000a86DQ',
#  '590m_rw-neg-te-0-584',
#  '590m_test_pos_rw-006f100000a86IW',
#  '590m_val_pos_rw-006f100000d6wRL',
#  '590m_rw-neg-te-0-550',
#  '590m_val_pos_rw-006f100000d6wQX',
#  '590m_test_pos_rw-006f100000d7cjc',
#  '590m_rw-neg-te-0-368',
#  '590m_test_pos_rw-006f100000d7icq',
#  '590m_rw-neg-te-0-72',
#  '590m_val_pos_rw-006f100000cPuua',
#  '590m_val_pos_rw-006f100000a86Dd',
#  '590m_rw-neg-te-0-16',
#  '590m_val_pos_rw-006f100000d7wvj',
#  '590m_rw-neg-te-0-47',
#  '590m_val_pos_rw-006f100000d7Q9c',
#  '590m_val_pos_rw-006f100000d761f',
#  '590m_rw-neg-te-0-579',
#  '590m_test_pos_rw-006f100000eescb',
#  '590m_test_pos_rw-006f100000d7EQE',
#  '590m_rw-neg-te-0-398',
#  '590m_val_pos_rw-006f100000eeuxr',
#  '590m_rw-neg-te-0-593',
#  '590m_rw-neg-te-0-101',
#  '590m_val_pos_rw-006f100000bh0JK',
#  '590m_rw-neg-te-0-430',
#  '590m_val_pos_rw-006f100000a86Dh',
#  '590m_rw-neg-te-0-342',
#  '590m_test_pos_rw-006f100000ZQRq1',
#  '590m_rw-neg-te-0-137',
#  '590m_rw-neg-te-0-372',
#  '590m_test_pos_rw-006f100000d7icb',
#  '590m_test_pos_rw-006f100000ef7eY',
#  '590m_rw-neg-te-0-296',
#  '590m_val_pos_rw-006f100000d7Q5q',
#  '590m_test_pos_rw-006f100000eesiP',
#  '590m_rw-neg-te-0-257',
#  '590m_rw-neg-te-0-274',
#  '590m_rw-neg-te-0-318',
#  '590m_test_pos_rw-006f100000a86Hd',
#  '590m_rw-neg-te-0-272',
#  '590m_rw-neg-te-0-527',
#  '590m_val_pos_rw-006f100000d7QAB',
#  '590m_rw-neg-te-0-213',
#  '590m_rw-neg-te-0-554',
#  '590m_rw-neg-te-0-441',
#  '590m_rw-neg-te-0-227',
#  '590m_rw-neg-te-0-462',
#  '590m_rw-neg-te-0-532',
#  '590m_val_pos_rw-006f100000ZQRkO',
#  '590m_rw-neg-te-0-355',
#  '590m_rw-neg-te-0-328',
#  '590m_rw-neg-te-0-230',
#  '590m_test_pos_rw-006f100000eekXv',
#  '590m_val_pos_rw-006f100000a86GY',
#  '590m_rw-neg-te-0-438',
#  '590m_rw-neg-te-0-267',
#  '590m_val_pos_rw-006f100000d761G',
#  '590m_test_pos_rw-006f100000a86ES',
#  '590m_test_pos_rw-006f100000biK9r',
#  '590m_rw-neg-te-0-556',
#  '590m_rw-neg-te-0-526',
#  '590m_test_pos_rw-006f100000eekWs',
#  '590m_test_pos_rw-006f100000eelYi',
#  '590m_test_pos_rw-006f100000a86D6',
#  '590m_rw-neg-te-0-224',
#  '590m_val_pos_rw-006f100000d761V',
#  '590m_rw-neg-te-0-611',
#  '590m_val_pos_rw-006f100000d7QQO',
#  '590m_rw-neg-te-0-574',
#  '590m_rw-neg-te-0-312',
#  '590m_rw-neg-te-0-289',
#  '590m_rw-neg-te-0-344',
#  '590m_rw-neg-val-0-241',
#  '590m_rw-neg-te-0-596',
#  '590m_test_pos_rw-006f100000eevM6',
#  '590m_val_pos_rw-006f100000ZQRq7',
#  '590m_rw-neg-te-0-114',
#  '590m_test_pos_rw-006f100000eekX7',
#  '590m_test_pos_rw-006f100000eelq8',
#  '590m_test_pos_rw-006f100000a86DI',
#  '590m_val_pos_rw-006f100000a86DA',
#  '590m_rw-neg-te-0-449',
#  '590m_rw-neg-te-0-597',
#  '590m_rw-neg-te-0-524',
#  '590m_val_pos_rw-006f100000ary6h',
#  '590m_rw-neg-te-0-288',
#  '590m_val_pos_rw-006f100000d7iew',
#  '590m_test_pos_rw-006f100000d8AoF',
#  '590m_test_pos_rw-006f100000biK9K',
#  '590m_rw-neg-te-0-164',
#  '590m_test_pos_rw-006f100000a86Cu',
#  '590m_test_pos_rw-006f100000d7ktK',
#  '590m_test_pos_rw-006f100000d7jDX',
#  '590m_rw-neg-te-0-581',
#  '590m_val_pos_rw-006f100000d7x5A',
#  '590m_val_pos_rw-006f100000a86EC',
#  '590m_test_pos_rw-006f100000d6kst',
#  '590m_test_pos_rw-006f100000d75zF',
#  '590m_test_pos_rw-006f100000d6wRp',
#  '590m_rw-neg-te-0-215',
#  '590m_test_pos_rw-006f100000c5jCG',
#  '590m_rw-neg-te-0-17',
#  '590m_rw-neg-te-0-453',
#  '590m_rw-neg-te-0-93',
#  '590m_rw-neg-te-0-228',
#  '590m_test_pos_rw-006f100000ef7jJ',
#  '590m_rw-neg-te-0-269',
#  '590m_rw-neg-te-0-408',
#  '590m_rw-neg-te-0-108',
#  '590m_rw-neg-te-0-349',
#  '590m_rw-neg-te-0-602',
#  '590m_test_pos_rw-006f100000d767N',
#  '590m_val_pos_rw-006f100000d6wQm',
#  '590m_rw-neg-te-0-119',
#  '590m_test_pos_rw-006f100000eekXg',
#  '590m_test_pos_rw-006f100000d7616',
#  '590m_val_pos_rw-006f100000dhpDZ',
#  '590m_rw-neg-te-0-36',
#  '590m_test_pos_rw-006f100000eevMa',
#  '590m_val_pos_rw-006f100000d7wuv',
#  '590m_rw-neg-te-0-495',
#  '590m_test_pos_rw-006f100000d6wRk',
#  '590m_rw-neg-te-0-3',
#  '590m_val_pos_rw-006f100000bgzS3',
#  '590m_rw-neg-te-0-4',
#  '590m_val_pos_rw-006f100000a86DG',
#  '590m_test_pos_rw-006f100000d7Q98',
#  '590m_test_pos_rw-006f100000ef7eT',
#  '590m_rw-neg-te-0-376',
#  '590m_rw-neg-te-0-302',
#  '590m_rw-neg-te-0-11',
#  '590m_rw-neg-te-0-360',
#  '590m_rw-neg-te-0-149',
#  '590m_test_pos_rw-006f100000eekcK',
#  '590m_rw-neg-te-0-197',
#  '590m_rw-neg-te-0-123',
#  '590m_val_pos_rw-006f100000d7Q5H',
#  '590m_rw-neg-te-0-154',
#  '590m_test_pos_rw-006f100000cMQ0C',
#  '590m_rw-neg-te-0-138',
#  '590m_rw-neg-te-0-413',
#  '590m_rw-neg-te-0-386',
#  '590m_val_pos_rw-006f100000a86G4',
#  '590m_val_pos_rw-006f100000d762E',
#  '590m_rw-neg-te-0-68',
#  '590m_val_pos_rw-006f100000d7jHK',
#  '590m_val_pos_rw-006f100000d762T',
#  '590m_test_pos_rw-006f100000dhyai',
#  '590m_val_pos_rw-006f100000d6wRB',
#  '590m_test_pos_rw-006f100000d7cnF',
#  '590m_test_pos_rw-006f100000ZQRq4',
#  '590m_rw-neg-te-0-158',
#  '590m_rw-neg-te-0-271',
#  '590m_test_pos_rw-006f100000d7Q8j',
#  '590m_rw-neg-te-0-240',
#  '590m_rw-neg-te-0-400',
#  '590m_test_pos_rw-006f100000efEfu',
#  '590m_rw-neg-te-0-253',
#  '590m_test_pos_rw-006f100000eevL3',
#  '590m_rw-neg-te-0-234',
#  '590m_rw-neg-te-0-394',
#  '590m_test_pos_rw-006f100000ef7en',
#  '590m_rw-neg-te-0-172',
#  '590m_rw-neg-te-0-522',
#  '590m_rw-neg-te-0-446',
#  '590m_test_pos_rw-006f100000a86DW',
#  '590m_rw-neg-te-0-399',
#  '590m_val_pos_rw-006f100000a86GK',
#  '590m_rw-neg-te-0-295',
#  '590m_val_pos_rw-006f100000a86EA',
#  '590m_test_pos_rw-006f100000d8AoP',
#  '590m_rw-neg-te-0-252',
#  '590m_val_pos_rw-006f100000d7wv5',
#  '590m_val_pos_rw-006f100000fHqCo',
#  '590m_test_pos_rw-006f100000d7ktA',
#  '590m_test_pos_rw-006f100000eessK',
#  '590m_rw-neg-te-0-298',
#  '590m_test_pos_rw-006f100000d7ibJ',
#  '590m_test_pos_rw-006f100000a86HY',
#  '590m_test_pos_rw-006f100000a86Hn',
#  '590m_rw-neg-te-0-299',
#  '590m_test_pos_rw-006f100000a86Dj',
#  '590m_rw-neg-te-0-146',
#  '590m_rw-neg-te-0-135',
#  '590m_test_pos_rw-006f100000cMOsW',
#  '590m_test_pos_rw-006f100000eekXH',
#  '590m_test_pos_rw-006f100000efEkk',
#  '590m_rw-neg-te-0-97',
#  '590m_test_pos_rw-006f100000a86Hj',
#  '590m_rw-neg-te-0-374',
#  '590m_test_pos_rw-006f100000eeqpo',
#  '590m_rw-neg-te-0-100',
#  '590m_val_pos_rw-006f100000ZQRkQ',
#  '590m_rw-neg-te-0-546',
#  '590m_test_pos_rw-006f100000eevOR',
#  '590m_rw-neg-te-0-422',
#  '590m_rw-neg-te-0-494',
#  '590m_test_pos_rw-006f100000d7EQx',
#  '590m_test_pos_rw-006f100000c5ivZ',
#  '590m_rw-neg-te-0-618',
#  '590m_rw-neg-te-0-562',
#  '590m_rw-neg-te-0-404',
#  '590m_test_pos_rw-006f100000efHAC',
#  '590m_rw-neg-te-0-203',
#  '590m_rw-neg-te-0-470',
#  '590m_test_pos_rw-006f100000d7bAq',
#  '590m_val_pos_rw-006f100000d7Q9S',
#  '590m_val_pos_rw-006f100000d6kt3',
#  '590m_rw-neg-te-0-8',
#  '590m_rw-neg-te-0-380',
#  '590m_rw-neg-te-0-387',
#  '590m_test_pos_rw-006f100000d6wGd',
#  '590m_test_pos_rw-006f100000d7ESA',
#  '590m_rw-neg-te-0-113',
#  '590m_rw-neg-te-0-24',
#  '590m_test_pos_rw-006f100000a86DY',
#  '590m_test_pos_rw-006f100000eekYo',
#  '590m_rw-neg-te-0-244',
#  '590m_rw-neg-te-0-418',
#  '590m_val_pos_rw-006f100000a86D7',
#  '590m_val_pos_rw-006f100000d6wBU',
#  '590m_test_pos_rw-006f100000ef7jO',
#  '590m_rw-neg-te-0-70',
#  '590m_test_pos_rw-006f100000eevLS',
#  '590m_val_pos_rw-006f100000a86G1',
#  '590m_val_pos_rw-006f100000bKyu7',
#  '590m_val_pos_rw-006f100000d7wul',
#  '590m_rw-neg-te-0-27',
#  '590m_test_pos_rw-006f100000efEfp',
#  '590m_rw-neg-te-0-458',
#  '590m_test_pos_rw-006f100000d760c',
#  '590m_rw-neg-te-0-534',
#  '590m_rw-neg-te-0-305',
#  '590m_val_pos_rw-006f100000a86Fy',
#  '590m_rw-neg-te-0-258',
#  '590m_rw-neg-te-0-525',
#  '590m_rw-neg-val-0-232',
#  '590m_test_pos_rw-006f100000eeqqS',
#  '590m_test_pos_rw-006f100000ZQRqE',
#  '590m_rw-neg-te-0-150',
#  '590m_test_pos_rw-006f100000d7ERv',
#  '590m_val_pos_rw-006f100000d7QQi',
#  '590m_rw-neg-te-0-20',
#  '590m_rw-neg-te-0-565',
#  '590m_test_pos_rw-006f100000d7611',
#  '590m_test_pos_rw-006f100000eelkq',
#  '590m_rw-neg-te-0-545',
#  '590m_rw-neg-te-0-577',
#  '590m_val_pos_rw-006f100000d7Pr6',
#  '590m_test_pos_rw-006f100000biKAB',
#  '590m_test_pos_rw-006f100000d7kmx',
#  '590m_rw-neg-te-0-189',
#  '590m_rw-neg-te-0-243',
#  '590m_val_pos_rw-006f100000a86Gx',
#  '590m_test_pos_rw-006f100000a86Hm',
#  '590m_val_pos_rw-006f100000ZQRq6',
#  '590m_test_pos_rw-006f100000eekhA',
#  '590m_rw-neg-te-0-389',
#  '590m_rw-neg-val-0-233',
#  '590m_test_pos_rw-006f100000d7x5P',
#  '590m_test_pos_rw-006f100000a86Hw',
#  '590m_rw-neg-te-0-167',
#  '590m_test_pos_rw-006f100000a86HS',
#  '590m_rw-neg-te-0-519',
#  '590m_rw-neg-te-0-396',
#  '590m_val_pos_rw-006f100000d7ELA',
#  '590m_test_pos_rw-006f100000d760S',
#  '590m_val_pos_rw-006f100000d7EZH',
#  '590m_val_pos_rw-006f100000dhpCW',
#  '590m_test_pos_rw-006f100000eekYP',
#  '590m_rw-neg-te-0-201',
#  '590m_rw-neg-te-0-451',
#  '590m_rw-neg-te-0-363',
#  '590m_rw-neg-te-0-566',
#  '590m_rw-neg-te-0-89',
#  '590m_test_pos_rw-006f100000d7ET8',
#  '590m_rw-neg-te-0-184',
#  '590m_test_pos_rw-006f100000d7kkN',
#  '590m_val_pos_rw-006f100000d7Q5C',
#  '590m_val_pos_rw-006f100000d6krT',
#  '590m_rw-neg-te-0-268',
#  '590m_val_pos_rw-006f100000a86E4',
#  '590m_rw-neg-te-0-535',
#  '590m_test_pos_rw-006f100000efEfz',
#  '590m_test_pos_rw-006f100000a86D9',
#  '590m_rw-neg-te-0-56',
#  '590m_rw-neg-te-0-42',
#  '590m_rw-neg-te-0-605',
#  '590m_rw-neg-te-0-490',
#  '590m_val_pos_rw-006f100000d7iQL',
#  '590m_rw-neg-te-0-361',
#  '590m_test_pos_rw-006f100000d8Aiv',
#  '590m_rw-neg-te-0-157',
#  '590m_rw-neg-te-0-73',
#  '590m_rw-neg-te-0-479',
#  '590m_rw-neg-te-0-76',
#  '590m_rw-neg-te-0-447',
#  '590m_val_pos_rw-006f100000a86EU',
#  '590m_rw-neg-te-0-317',
#  '590m_val_pos_rw-006f100000ZQRqA',
#  '590m_val_pos_rw-006f100000a86E3',
#  '590m_val_pos_rw-006f100000d6wRf',
#  '590m_rw-neg-te-0-22',
#  '590m_rw-neg-te-0-412',
#  '590m_rw-neg-te-0-323',
#  '590m_test_pos_rw-006f100000cMz95',
#  '590m_test_pos_rw-006f100000eekgv',
#  '590m_rw-neg-te-0-521',
#  '590m_val_pos_rw-006f100000d7QQd',
#  '590m_val_pos_rw-006f100000a86Da',
#  '590m_val_pos_rw-006f100000asEzN',
#  '590m_val_pos_rw-006f100000d6mYQ',
#  '590m_test_pos_rw-006f100000a86Hk',
#  '590m_val_pos_rw-006f100000bgzEa',
#  '590m_rw-neg-te-0-237',
#  '590m_rw-neg-te-0-478',
#  '590m_rw-neg-te-0-69',
#  '590m_rw-neg-te-0-112',
#  '590m_rw-neg-te-0-601',
#  '590m_test_pos_rw-006f100000d8Aj5',
#  '590m_rw-neg-te-0-320',
#  '590m_rw-neg-te-0-335',
#  '590m_val_pos_rw-006f100000bh0hg',
#  '590m_rw-neg-te-0-454',
#  '590m_rw-neg-te-0-537',
#  '590m_rw-neg-te-0-120',
#  '590m_rw-neg-te-0-279',
#  '590m_val_pos_rw-006f100000bgzlZ',
#  '590m_test_pos_rw-006f100000d7igs',
#  '590m_rw-neg-te-0-529',
#  '590m_val_pos_rw-006f100000d7ELU',
#  '590m_val_pos_rw-006f100000bNTvY',
#  '590m_test_pos_rw-006f100000d7ER7',
#  '590m_rw-neg-te-0-204',
#  '590m_test_pos_rw-006f100000d7bAg',
#  '590m_test_pos_rw-006f100000d7idt',
#  '590m_rw-neg-te-0-292',
#  '590m_rw-neg-te-0-607',
#  '590m_rw-neg-te-0-303',
#  '590m_rw-neg-te-0-254',
#  '590m_rw-neg-te-0-437',
#  '590m_rw-neg-te-0-35',
#  '590m_val_pos_rw-006f100000d6mYV',
#  '590m_rw-neg-te-0-512',
#  '590m_test_pos_rw-006f100000bMJz7',
#  '590m_rw-neg-te-0-520',
#  '590m_test_pos_rw-006f100000asYQD',
#  '590m_rw-neg-te-0-195',
#  '590m_rw-neg-te-0-518',
#  '590m_val_pos_rw-006f100000d7Q4s',
#  '590m_test_pos_rw-006f100000efEeX',
#  '590m_rw-neg-te-0-130',
#  '590m_rw-neg-te-0-375',
#  '590m_test_pos_rw-006f100000eekgg',
#  '590m_val_pos_rw-006f100000dhyeV',
#  '590m_rw-neg-te-0-59',
#  '590m_rw-neg-te-0-346',
#  '590m_rw-neg-te-0-338',
#  '590m_test_pos_rw-006f100000efEeh',
#  '590m_rw-neg-te-0-290',
#  '590m_rw-neg-te-0-104',
#  '590m_rw-neg-te-0-91',
#  '590m_test_pos_rw-006f100000d7bAR',
#  '590m_test_pos_rw-006f100000d7jDc',
#  '590m_rw-neg-te-0-117',
#  '590m_test_pos_rw-006f100000d767S',
#  '590m_rw-neg-te-0-174',
#  '590m_rw-neg-te-0-415',
#  '590m_rw-neg-te-0-471',
#  '590m_rw-neg-te-0-139',
#  '590m_test_pos_rw-006f100000bgeFT',
#  '590m_rw-neg-te-0-280',
#  '590m_val_pos_rw-006f100000d6wC3',
#  '590m_rw-neg-te-0-171',
#  '590m_rw-neg-te-0-381',
#  '590m_rw-neg-te-0-345',
#  '590m_rw-neg-te-0-402',
#  '590m_rw-neg-te-0-136',
#  '590m_rw-neg-te-0-508',
#  '590m_test_pos_rw-006f100000a86D0',
#  '590m_test_pos_rw-006f100000efHIu',
#  '590m_rw-neg-te-0-62',
#  '590m_rw-neg-te-0-7',
#  '590m_rw-neg-te-0-165',
#  '590m_rw-neg-te-0-351',
#  '590m_test_pos_rw-006f100000eekgM',
#  '590m_rw-neg-te-0-589',
#  '590m_test_pos_rw-006f100000ef7jE',
#  '590m_test_pos_rw-006f100000d7bAH',
#  '590m_test_pos_rw-006f100000d7jAs',
#  '590m_rw-neg-te-0-262',
#  '590m_test_pos_rw-006f100000d8AoK',
#  '590m_test_pos_rw-006f100000d7678',
#  '590m_rw-neg-te-0-435',
#  '590m_test_pos_rw-006f100000efHCI',
#  '590m_rw-neg-te-0-414',
#  '590m_rw-neg-te-0-80',
#  '590m_rw-neg-te-0-384',
#  '590m_rw-neg-te-0-54',
#  '590m_val_pos_rw-006f100000dhyea',
#  '590m_rw-neg-te-0-34',
#  '590m_val_pos_rw-006f100000a86GU',
#  '590m_test_pos_rw-006f100000efEkp',
#  '590m_val_pos_rw-006f100000d7ETm',
#  '590m_test_pos_rw-006f100000d7ib4',
#  '590m_test_pos_rw-006f100000ZQRq0',
#  '590m_rw-neg-te-0-124',
#  '590m_test_pos_rw-006f100000a86G6',
#  '590m_rw-neg-te-0-544',
#  '590m_test_pos_rw-006f100000eekXC',
#  '590m_rw-neg-te-0-209',
#  '590m_test_pos_rw-006f100000eekXq',
#  '590m_rw-neg-te-0-427',
#  '590m_rw-neg-te-0-604',
#  '590m_rw-neg-te-0-176',
#  '590m_rw-neg-te-0-208',
#  '590m_rw-neg-te-0-477',
#  '590m_val_pos_rw-006f100000d7Q6K',
#  '590m_rw-neg-te-0-483',
#  '590m_rw-neg-te-0-497',
#  '590m_rw-neg-te-0-456',
#  '590m_rw-neg-te-0-420',
#  '590m_val_pos_rw-006f100000a86D5',
#  '590m_rw-neg-te-0-583',
#  '590m_test_pos_rw-006f100000d7wvt',
#  '590m_rw-neg-te-0-397',
#  '590m_rw-neg-te-0-493',
#  '590m_rw-neg-te-0-71',
#  '590m_rw-neg-te-0-159',
#  '590m_test_pos_rw-006f100000ZQRpx',
#  '590m_rw-neg-te-0-496',
#  '590m_rw-neg-te-0-194',
#  '590m_rw-neg-val-0-236',
#  '590m_rw-neg-te-0-191',
#  '590m_rw-neg-te-0-255',
#  '590m_val_pos_rw-006f100000a86De',
#  '590m_rw-neg-te-0-15',
#  '590m_test_pos_rw-006f100000eekVG',
#  '590m_rw-neg-te-0-180',
#  '590m_test_pos_rw-006f100000efhn7',
#  '590m_val_pos_rw-006f100000d6wBZ',
#  '590m_test_pos_rw-006f100000a86I4',
#  '590m_rw-neg-te-0-183',
#  '590m_val_pos_rw-006f100000d7Q9w',
#  '590m_rw-neg-te-0-92',
#  '590m_rw-neg-te-0-122',
#  '590m_test_pos_rw-006f100000eelvm',
#  '590m_rw-neg-te-0-505',
#  '590m_test_pos_rw-006f100000d7QAG',
#  '590m_val_pos_rw-006f100000a86Gl',
#  '590m_rw-neg-te-0-390',
#  '590m_rw-neg-te-0-426',
#  '590m_rw-neg-te-0-541',
#  '590m_test_pos_rw-006f100000a86HV',
#  '590m_val_pos_rw-006f100000d7wvK',
#  '590m_rw-neg-val-0-240',
#  '590m_test_pos_rw-006f100000a86Cy',
#  '590m_test_pos_rw-006f100000eekXW',
#  '590m_val_pos_rw-006f100000d6wBy',
#  '590m_test_pos_rw-006f100000d7kng',
#  '590m_rw-neg-te-0-214',
#  '590m_test_pos_rw-006f100000eesiU',
#  '590m_val_pos_rw-006f100000d6wCI',
#  '590m_test_pos_rw-006f100000eekg7',
#  '590m_test_pos_rw-006f100000eeqsE',
#  '590m_rw-neg-te-0-585',
#  '590m_test_pos_rw-006f100000eekcP',
#  '590m_test_pos_rw-006f100000eesit',
#  '590m_test_pos_rw-006f100000a86Hl',
#  '590m_test_pos_rw-006f100000ZQRq8',
#  '590m_test_pos_rw-006f100000a86Hu',
#  '590m_rw-neg-te-0-333',
#  '590m_test_pos_rw-006f100000a86I1',
#  '590m_rw-neg-te-0-509',
#  '590m_test_pos_rw-006f100000eekgl',
#  '590m_test_pos_rw-006f100000aATjC',
#  '590m_rw-neg-te-0-18',
#  '590m_val_pos_rw-006f100000ZQRpr',
#  '590m_test_pos_rw-006f100000d760D',
#  '590m_val_pos_rw-006f100000a86Fa',
#  '590m_rw-neg-te-0-378',
#  '590m_test_pos_rw-006f100000efEl9',
#  '590m_test_pos_rw-006f100000d7bA7',
#  '590m_test_pos_rw-006f100000d7kl1',
#  '590m_rw-neg-te-0-571',
#  '590m_rw-neg-te-0-131',
#  '590m_rw-neg-te-0-548',
#  '590m_rw-neg-te-0-343',
#  '590m_rw-neg-te-0-185',
#  '590m_rw-neg-te-0-90',
#  '590m_test_pos_rw-006f100000bMJzq',
#  '590m_rw-neg-te-0-586',
#  '590m_test_pos_rw-006f100000a86Hh',
#  '590m_rw-neg-te-0-94',
#  '590m_val_pos_rw-006f100000eeuuO',
#  '590m_val_pos_rw-006f100000d7Q5g',
#  '590m_rw-neg-te-0-178',
#  '590m_val_pos_rw-006f100000ZQRqC',
#  '590m_rw-neg-te-0-65',
#  '590m_test_pos_rw-006f100000d8AoA',
#  '590m_test_pos_rw-006f100000c5V2b',
#  '590m_test_pos_rw-006f100000eekhZ',
#  '590m_test_pos_rw-006f100000d7crl',
#  '590m_rw-neg-te-0-207',
#  '590m_test_pos_rw-006f100000d7Q9r',
#  '590m_rw-neg-te-0-102',
#  '590m_rw-neg-te-0-216',
#  '590m_val_pos_rw-006f100000d761Q',
#  '590m_rw-neg-te-0-107',
#  '590m_test_pos_rw-006f100000d7jDh',
#  '590m_test_pos_rw-006f100000d7icM',
#  '590m_rw-neg-val-0-235',
#  '590m_test_pos_rw-006f100000eekgR',
#  '590m_rw-neg-te-0-348',
#  '590m_test_pos_rw-006f100000eeqt7',
#  '590m_val_pos_rw-006f100000dhpCb',
#  '590m_val_pos_rw-006f100000a86DE',
#  '590m_test_pos_rw-006f100000d7bAC',
#  '590m_rw-neg-te-0-168',
#  '590m_rw-neg-te-0-219',
#  '590m_rw-neg-te-0-0',
#  '590m_rw-neg-te-0-177',
#  '590m_test_pos_rw-006f100000ZQRkH',
#  '590m_rw-neg-te-0-536',
#  '590m_rw-neg-te-0-433',
#  '590m_test_pos_rw-006f100000d8AjF',
#  '590m_rw-neg-te-0-356',
#  '590m_test_pos_rw-006f100000eelnp',
#  '590m_val_pos_rw-006f100000d7QQT',
#  '590m_rw-neg-te-0-57',
#  '590m_val_pos_rw-006f100000d762J',
#  '590m_test_pos_rw-006f100000eesdU',
#  '590m_rw-neg-te-0-436',
#  '590m_val_pos_rw-006f100000d762Y',
#  '590m_val_pos_rw-006f100000a86GQ',
#  '590m_val_pos_rw-006f100000a86Dg',
#  '590m_test_pos_rw-006f100000cMPMM',
#  '590m_rw-neg-te-0-573',
#  '590m_rw-neg-te-0-111',
#  '590m_rw-neg-te-0-75',
#  '590m_test_pos_rw-006f100000eekhe',
#  '590m_test_pos_rw-006f100000d7knH',
#  '590m_val_pos_rw-006f100000c5pcI',
#  '590m_rw-neg-te-0-28',
#  '590m_rw-neg-te-0-501',
#  '590m_rw-neg-te-0-514',
#  '590m_val_pos_rw-006f100000d7wvF',
#  '590m_test_pos_rw-006f100000a86Hr',
#  '590m_test_pos_rw-006f100000d766Z',
#  '590m_rw-neg-te-0-417',
#  '590m_test_pos_rw-006f100000eeqss',
#  '590m_val_pos_rw-006f100000d6wCN',
#  '590m_test_pos_rw-006f100000d7hMW',
#  '590m_rw-neg-te-0-222',
#  '590m_test_pos_rw-006f100000a86HT',
#  '590m_test_pos_rw-006f100000eevN9',
#  '590m_test_pos_rw-006f100000d6wGE',
#  '590m_rw-neg-te-0-109',
#  '590m_val_pos_rw-006f100000d7EMS',
#  '590m_rw-neg-te-0-486',
#  '590m_test_pos_rw-006f100000eekYj',
#  '590m_rw-neg-te-0-603',
#  '590m_rw-neg-te-0-52',
#  '590m_test_pos_rw-006f100000d760w',
#  '590m_test_pos_rw-006f100000d7EQO',
#  '590m_rw-neg-te-0-475',
#  '590m_val_pos_rw-006f100000bKz7z',
#  '590m_rw-neg-te-0-163',
#  '590m_rw-neg-te-0-315',
#  '590m_val_pos_rw-006f100000a86HQ',
#  '590m_rw-neg-te-0-587',
#  '590m_test_pos_rw-006f100000eevLh',
#  '590m_val_pos_rw-006f100000d7EMc',
#  '590m_test_pos_rw-006f100000biKAa',
#  '590m_test_pos_rw-006f100000d7ic2',
#  '590m_rw-neg-te-0-616',
#  '590m_test_pos_rw-006f100000d7ETh',
#  '590m_rw-neg-te-0-499',
#  '590m_test_pos_rw-006f100000d7wvA',
#  '590m_rw-neg-te-0-452',
#  '590m_test_pos_rw-006f100000a86Hq',
#  '590m_test_pos_rw-006f100000d7ibT',
#  '590m_val_pos_rw-006f100000a86DJ',
#  '590m_test_pos_rw-006f100000c5VQs',
#  '590m_rw-neg-te-0-278',
#  '590m_test_pos_rw-006f100000cPpL8',
#  '590m_rw-neg-te-0-245',
#  '590m_rw-neg-te-0-192',
#  '590m_rw-neg-te-0-340',
#  '590m_val_pos_rw-006f100000d7Q6F',
#  '590m_rw-neg-te-0-594',
#  '590m_test_pos_rw-006f100000eesiy',
#  '590m_test_pos_rw-006f100000ZQRq2',
#  '590m_rw-neg-te-0-126',
#  '590m_rw-neg-te-0-407',
#  '590m_val_pos_rw-006f100000d7wvZ',
#  '590m_test_pos_rw-006f100000d767I',
#  '590m_rw-neg-te-0-547',
#  '590m_rw-neg-te-0-281',
#  '590m_val_pos_rw-006f100000d7x5K',
#  '590m_rw-neg-te-0-502',
#  '590m_val_pos_rw-006f100000d78Ou',
#  '590m_test_pos_rw-006f100000eekfx',
#  '590m_rw-neg-te-0-329',
#  '590m_val_pos_rw-006f100000d7ETr',
#  '590m_val_pos_rw-006f100000d7x5e',
#  '590m_rw-neg-te-0-25',
#  '590m_rw-neg-te-0-609',
#  '590m_rw-neg-te-0-474',
#  '590m_rw-neg-te-0-232',
#  '590m_rw-neg-te-0-66',
#  '590m_rw-neg-te-0-140',
#  '590m_rw-neg-te-0-457',
#  '590m_test_pos_rw-006f100000d6wHl',
#  '590m_val_pos_rw-006f100000d7GsI',
#  '590m_rw-neg-te-0-50',
#  '590m_test_pos_rw-006f100000d7kmJ',
#  '590m_test_pos_rw-006f100000a86DP',
#  '590m_rw-neg-te-0-236',
#  '590m_rw-neg-te-0-169',
#  '590m_rw-neg-te-0-51',
#  '590m_val_pos_rw-006f100000d7EZM',
#  '590m_val_pos_rw-006f100000d7ibs',
#  '590m_rw-neg-te-0-256',
#  '590m_test_pos_rw-006f100000d761B',
#  '590m_rw-neg-te-0-429',
#  '590m_rw-neg-te-0-405',
#  '590m_rw-neg-te-0-530',
#  '590m_rw-neg-te-0-153',
#  '590m_test_pos_rw-006f100000d6wGn',
#  '590m_val_pos_rw-006f100000d7QQn',
#  '590m_val_pos_rw-006f100000a86Dz',
#  '590m_test_pos_rw-006f100000dhmUv',
#  '590m_rw-neg-te-0-134',
#  '590m_rw-neg-te-0-385',
#  '590m_val_pos_rw-006f100000d7ETD',
#  '590m_rw-neg-te-0-325',
#  '590m_rw-neg-te-0-151',
#  '590m_test_pos_rw-006f100000c5V5L',
#  '590m_rw-neg-te-0-575',
#  '590m_rw-neg-te-0-403',
#  '590m_rw-neg-te-0-85',
#  '590m_rw-neg-te-0-410',
#  '590m_rw-neg-te-0-359',
#  '590m_rw-neg-te-0-125',
#  '590m_val_pos_rw-006f100000d1hPv',
#  '590m_rw-neg-te-0-211',
#  '590m_rw-neg-te-0-432',
#  '590m_rw-neg-te-0-459',
#  '590m_test_pos_rw-006f100000eekgq',
#  '590m_val_pos_rw-006f100000a86EN',
#  '590m_rw-neg-te-0-276',
#  '590m_rw-neg-val-0-237',
#  '590m_rw-neg-te-0-455',
#  '590m_rw-neg-te-0-6',
#  '590m_rw-neg-te-0-63',
#  '590m_val_pos_rw-006f100000a86E1',
#  '590m_test_pos_rw-006f100000a86HL',
#  '590m_test_pos_rw-006f100000d7khO',
#  '590m_rw-neg-te-0-307',
#  '590m_test_pos_rw-006f100000efHAb',
#  '590m_val_pos_rw-006f100000ZQRpy',
#  '590m_rw-neg-te-0-582',
#  '590m_rw-neg-te-0-326',
#  '590m_rw-neg-te-0-401',
#  '590m_rw-neg-te-0-549',
#  '590m_test_pos_rw-006f100000d7icg',
#  '590m_rw-neg-te-0-411',
#  '590m_rw-neg-te-0-572',
#  '590m_val_pos_rw-006f100000d7QSo',
#  '590m_rw-neg-te-0-472',
#  '590m_val_pos_rw-006f100000d7Q4x',
#  '590m_rw-neg-te-0-377',
#  '590m_rw-neg-te-0-235',
#  '590m_test_pos_rw-006f100000eekgH',
#  '590m_val_pos_rw-006f100000d7EMX',
#  '590m_rw-neg-te-0-406',
#  '590m_rw-neg-te-0-96',
#  '590m_rw-neg-te-0-612',
#  '590m_test_pos_rw-006f100000biKAk',
#  '590m_test_pos_rw-006f100000eekhU',
#  '590m_test_pos_rw-006f100000d7Q9h',
#  '590m_test_pos_rw-006f100000d760X',
#  '590m_test_pos_rw-006f100000d7ESP',
#  '590m_rw-neg-te-0-448',
#  '590m_rw-neg-te-0-10',
#  '590m_test_pos_rw-006f100000eevMu',
#  '590m_val_pos_rw-006f100000d7EZR',
#  '590m_test_pos_rw-006f100000d6wRa',
#  '590m_test_pos_rw-006f100000a86HW',
#  '590m_val_pos_rw-006f100000d761L',
#  '590m_test_pos_rw-006f100000eekXl',
#  '590m_val_pos_rw-006f100000d761a',
#  '590m_test_pos_rw-006f100000d7ihb',
#  '590m_test_pos_rw-006f100000eelvc',
#  '590m_val_pos_rw-006f100000a86E2',
#  '590m_rw-neg-te-0-26',
#  '590m_val_pos_rw-006f100000d7Q9X',
#  '590m_val_pos_rw-006f100000d7ETS',
#  '590m_test_pos_rw-006f100000eesd5',
#  '590m_rw-neg-te-0-469',
#  '590m_rw-neg-te-0-552',
#  '590m_test_pos_rw-006f100000d7wvo',
#  '590m_rw-neg-te-0-77',
#  '590m_rw-neg-val-0-238',
#  '590m_val_pos_rw-006f100000d7Q5R',
#  '590m_rw-neg-te-0-515',
#  '590m_rw-neg-te-0-229',
#  '590m_test_pos_rw-006f100000a86Hx',
#  '590m_rw-neg-te-0-166',
#  '590m_rw-neg-te-0-12',
#  '590m_rw-neg-te-0-568',
#  ...}

# %%
len(unique_fnames.difference(unique_lonlat_names))
# Out:
# 1242

# %%
unique_fnames.difference(unique_lonlat_names)
# Out:
# {'590m_train_pos_rw-006f100000a86Dg',
#  '590m_rw-neg-tr-upper-0-575',
#  '590m_train_pos_rw-006f100000eekVG',
#  '590m_train_pos_rw-006f100000d761a',
#  '590m_ug-neg-te-0-78',
#  '590m_ug-neg-te-0-50',
#  '590m_train_pos_rw-006f100000bKyu7',
#  '590m_train_pos_rw-006f100000a86IW',
#  '590m_rw-neg-tr-lower-0-496',
#  '590m_ug-neg-te-0-119',
#  '590m_train_pos_rw-006f100000a86EX',
#  '590m_rw-neg-tr-lower-0-539',
#  '590m_ug-neg-te-0-29',
#  '590m_train_pos_rw-006f100000eeuuO',
#  '590m_rw-neg-tr-upper-0-464',
#  '590m_rw-neg-tr-lower-0-545',
#  '590m_ug-neg-te-0-170',
#  '590m_train_pos_rw-006f100000Zt6Uj',
#  '590m_rw-neg-tr-lower-0-507',
#  '590m_rw-neg-tr-upper-0-460',
#  '590m_ug-neg-te-0-167',
#  '590m_rw-neg-tr-upper-0-440',
#  '590m_rw-neg-tr-upper-0-467',
#  '590m_rw-neg-tr-lower-0-486',
#  '590m_rw-neg-tr-upper-0-427',
#  '590m_train_pos_rw-006f100000bgtSn',
#  '590m_rw-neg-tr-lower-0-554',
#  '590m_val_pos_rw-006f100000d7Q9m',
#  '590m_train_pos_rw-006f100000d761L',
#  '590m_ug-neg-te-0-132',
#  '590m_ug-neg-te-0-93',
#  '590m_train_pos_rw-006f100000a86G7',
#  '590m_train_pos_rw-006f100000d7EZR',
#  '590m_train_pos_rw-006f100000a86Hn',
#  '590m_rw-neg-tr-upper-0-564',
#  '590m_rw-neg-tr-upper-0-420',
#  '590m_train_pos_rw-006f100000d7ESZ',
#  '590m_train_pos_rw-006f100000d6wBy',
#  '590m_ug-neg-te-0-137',
#  '590m_ug-neg-te-0-160',
#  '590m_rw-neg-tr-upper-0-508',
#  '590m_val_pos_rw-006f100000eelvc',
#  '590m_ug-neg-te-0-227',
#  '590m_train_pos_rw-006f100000d761z',
#  '590m_train_pos_rw-006f100000dhyef',
#  '590m_train_pos_rw-006f100000d7EZH',
#  '590m_rw-neg-tr-upper-0-563',
#  '590m_rw-neg-tr-upper-0-416',
#  '590m_ug-neg-te-0-28',
#  '590m_ug-neg-te-0-95',
#  '590m_ug-neg-te-0-145',
#  '590m_val_pos_rw-006f100000d75zo',
#  '590m_train_pos_rw-006f100000bgtaS',
#  '590m_rw-neg-tr-upper-0-468',
#  '590m_val_pos_rw-006f100000a86HL',
#  '590m_rw-neg-tr-upper-0-454',
#  '590m_rw-neg-tr-upper-0-458',
#  '590m_ug-neg-te-0-76',
#  '590m_ug-neg-te-0-41',
#  '590m_rw-neg-tr-upper-0-503',
#  '590m_rw-neg-tr-upper-0-552',
#  '590m_train_pos_rw-006f100000a86DS',
#  '590m_val_pos_rw-006f100000d75ze',
#  '590m_rw-neg-tr-lower-0-588',
#  '590m_rw-neg-tr-upper-0-514',
#  '590m_ug-neg-te-0-156',
#  '590m_train_pos_rw-006f100000d7ieX',
#  '590m_val_pos_rw-006f100000eescv',
#  '590m_ug-neg-te-0-222',
#  '590m_train_pos_rw-006f100000d762J',
#  '590m_val_pos_rw-006f100000d760X',
#  '590m_train_pos_rw-006f100000a86Hy',
#  '590m_train_pos_rw-006f100000efEeh',
#  '590m_val_pos_rw-006f100000ZQRq0',
#  '590m_rw-neg-tr-lower-0-450',
#  '590m_ug-neg-te-0-85',
#  '590m_rw-neg-tr-lower-0-495',
#  '590m_val_pos_rw-006f100000eelYi',
#  '590m_rw-neg-tr-lower-0-572',
#  '590m_rw-neg-tr-lower-0-431',
#  '590m_val_pos_rw-006f100000d766o',
#  '590m_train_pos_rw-006f100000d7x5j',
#  '590m_train_pos_rw-006f100000efHAC',
#  '590m_val_pos_rw-006f100000d75zF',
#  '590m_rw-neg-tr-upper-0-480',
#  '590m_val_pos_rw-006f100000d8Aiv',
#  '590m_train_pos_rw-006f100000d7JCn',
#  '590m_rw-neg-tr-lower-0-490',
#  '590m_train_pos_rw-006f100000efEfu',
#  '590m_rw-neg-tr-lower-0-453',
#  '590m_val_pos_rw-006f100000eelq8',
#  '590m_val_pos_rw-006f100000eesiP',
#  '590m_rw-neg-tr-upper-0-414',
#  '590m_ug-neg-te-0-10',
#  '590m_train_pos_rw-006f100000a86HO',
#  '590m_train_pos_rw-006f100000d6wRB',
#  '590m_train_pos_rw-006f100000a86I3',
#  '590m_rw-neg-tr-lower-0-427',
#  '590m_ug-neg-te-0-26',
#  '590m_ug-neg-te-0-181',
#  '590m_ug-neg-te-0-139',
#  '590m_val_pos_rw-006f100000d8AoA',
#  '590m_ug-neg-te-0-165',
#  '590m_ug-neg-te-0-173',
#  '590m_ug-neg-te-0-31',
#  '590m_train_pos_rw-006f100000d6wBo',
#  '590m_ug-neg-te-0-112',
#  '590m_val_pos_rw-006f100000d7ibT',
#  '590m_rw-neg-tr-upper-0-542',
#  '590m_rw-neg-tr-lower-0-446',
#  '590m_ug-neg-te-0-25',
#  '590m_rw-neg-tr-upper-0-545',
#  '590m_rw-neg-tr-upper-0-588',
#  '590m_val_pos_rw-006f100000d75zj',
#  '590m_rw-neg-tr-upper-0-442',
#  '590m_train_pos_rw-006f100000biKAk',
#  '590m_train_pos_rw-006f100000efEkz',
#  '590m_train_pos_rw-006f100000d7kng',
#  '590m_rw-neg-tr-lower-0-548',
#  '590m_ug-neg-te-0-51',
#  '590m_val_pos_rw-006f100000d7EPz',
#  '590m_rw-neg-tr-lower-0-439',
#  '590m_train_pos_rw-006f100000ZQRq4',
#  '590m_rw-neg-tr-lower-0-574',
#  '590m_rw-neg-tr-upper-0-511',
#  '590m_train_pos_rw-006f100000a86DJ',
#  '590m_train_pos_rw-006f100000cMPMM',
#  '590m_rw-neg-tr-upper-0-495',
#  '590m_train_pos_rw-006f100000d6wRf',
#  '590m_rw-neg-tr-lower-0-570',
#  '590m_rw-neg-tr-upper-0-512',
#  '590m_rw-neg-tr-upper-0-478',
#  '590m_ug-neg-te-0-185',
#  '590m_train_pos_rw-006f100000a86DU',
#  '590m_rw-neg-tr-lower-0-559',
#  '590m_val_pos_rw-006f100000d6wHl',
#  '590m_train_pos_rw-006f100000d7Q5g',
#  '590m_train_pos_rw-006f100000d7EMN',
#  '590m_rw-neg-tr-upper-0-431',
#  '590m_rw-neg-tr-upper-0-530',
#  '590m_train_pos_rw-006f100000d7khO',
#  '590m_rw-neg-tr-lower-0-501',
#  '590m_ug-neg-te-0-187',
#  '590m_ug-neg-te-0-192',
#  '590m_rw-neg-tr-lower-0-510',
#  '590m_ug-neg-te-0-20',
#  '590m_rw-neg-tr-lower-0-442',
#  '590m_rw-neg-tr-lower-0-444',
#  '590m_train_pos_rw-006f100000d7Q5q',
#  '590m_train_pos_rw-006f100000ef7jJ',
#  '590m_train_pos_rw-006f100000cPI5w',
#  '590m_rw-neg-tr-lower-0-595',
#  '590m_ug-neg-te-0-151',
#  '590m_train_pos_rw-006f100000ZQRq6',
#  '590m_rw-neg-tr-upper-0-475',
#  '590m_rw-neg-tr-upper-0-447',
#  '590m_rw-neg-tr-upper-0-553',
#  '590m_val_pos_rw-006f100000ZQRq1',
#  '590m_rw-neg-tr-lower-0-456',
#  '590m_val_pos_rw-006f100000d760I',
#  '590m_val_pos_rw-006f100000d760D',
#  '590m_rw-neg-tr-lower-0-562',
#  '590m_ug-neg-te-0-38',
#  '590m_rw-neg-tr-lower-0-481',
#  '590m_val_pos_rw-006f100000d7bAg',
#  '590m_train_pos_rw-006f100000d7iQf',
#  '590m_rw-neg-tr-upper-0-428',
#  '590m_train_pos_rw-006f100000a86EW',
#  '590m_train_pos_rw-006f100000a86Dd',
#  '590m_val_pos_rw-006f100000eeqt7',
#  '590m_rw-neg-tr-lower-0-589',
#  '590m_rw-neg-tr-upper-0-477',
#  '590m_train_pos_rw-006f100000aA0hf',
#  '590m_val_pos_rw-006f100000d7ic2',
#  '590m_train_pos_rw-006f100000d7ELU',
#  '590m_train_pos_rw-006f100000d6wCI',
#  '590m_train_pos_rw-006f100000d7Q9D',
#  '590m_rw-neg-tr-lower-0-459',
#  '590m_train_pos_rw-006f100000a86Ho',
#  '590m_val_pos_rw-006f100000a86Cw',
#  '590m_rw-neg-tr-lower-0-555',
#  '590m_ug-neg-te-0-83',
#  '590m_rw-neg-tr-upper-0-535',
#  '590m_val_pos_rw-006f100000d7bA2',
#  '590m_ug-neg-te-0-9',
#  '590m_rw-neg-tr-upper-0-524',
#  '590m_val_pos_rw-006f100000d7bAq',
#  '590m_train_pos_rw-006f100000a86Hp',
#  '590m_train_pos_rw-006f100000d7PqS',
#  '590m_val_pos_rw-006f100000d6kpD',
#  '590m_rw-neg-tr-upper-0-591',
#  '590m_train_pos_rw-006f100000efEem',
#  '590m_train_pos_rw-006f100000d7iew',
#  '590m_rw-neg-tr-lower-0-527',
#  '590m_ug-neg-te-0-58',
#  '590m_rw-neg-tr-lower-0-541',
#  '590m_train_pos_rw-006f100000d7x5K',
#  '590m_rw-neg-tr-lower-0-479',
#  '590m_rw-neg-tr-lower-0-417',
#  '590m_val_pos_rw-006f100000eekgR',
#  '590m_rw-neg-tr-lower-0-560',
#  '590m_val_pos_rw-006f100000d8AjF',
#  '590m_ug-neg-te-0-208',
#  '590m_ug-neg-te-0-69',
#  '590m_ug-neg-te-0-2',
#  '590m_train_pos_rw-006f100000d6ksK',
#  '590m_train_pos_rw-006f100000ZQRkP',
#  '590m_rw-neg-tr-upper-0-549',
#  '590m_train_pos_rw-006f100000c5pcI',
#  '590m_ug-neg-te-0-190',
#  '590m_rw-neg-tr-upper-0-461',
#  '590m_train_pos_rw-006f100000d6lDD',
#  '590m_val_pos_rw-006f100000eekcK',
#  '590m_val_pos_rw-006f100000a86DM',
#  '590m_train_pos_rw-006f100000d7wvK',
#  '590m_train_pos_rw-006f100000d7EMS',
#  '590m_rw-neg-tr-lower-0-569',
#  '590m_train_pos_rw-006f100000ZQRq9',
#  '590m_val_pos_rw-006f100000eesdU',
#  '590m_val_pos_rw-006f100000d7616',
#  '590m_val_pos_rw-006f100000d8AoK',
#  '590m_rw-neg-tr-lower-0-536',
#  '590m_train_pos_rw-006f100000ZQRq3',
#  '590m_rw-neg-tr-lower-0-585',
#  '590m_rw-neg-tr-upper-0-446',
#  '590m_rw-neg-tr-lower-0-471',
#  '590m_val_pos_rw-006f100000d760S',
#  '590m_train_pos_rw-006f100000ZQRkQ',
#  '590m_ug-neg-te-0-82',
#  '590m_ug-neg-te-0-218',
#  '590m_train_pos_rw-006f100000d7QA6',
#  '590m_val_pos_rw-006f100000d7Q9h',
#  '590m_rw-neg-tr-lower-0-457',
#  '590m_val_pos_rw-006f100000d7jAx',
#  '590m_val_pos_rw-006f100000d7jI3',
#  '590m_ug-neg-te-0-241',
#  '590m_train_pos_rw-006f100000d7wvF',
#  '590m_val_pos_rw-006f100000d7jDh',
#  '590m_val_pos_rw-006f100000d6kst',
#  '590m_train_pos_rw-006f100000a86Dy',
#  '590m_train_pos_rw-006f100000d7x5t',
#  '590m_val_pos_rw-006f100000d760c',
#  '590m_train_pos_rw-006f100000bgzlZ',
#  '590m_train_pos_rw-006f100000a86DG',
#  '590m_rw-neg-tr-lower-0-511',
#  '590m_rw-neg-tr-upper-0-456',
#  '590m_val_pos_rw-006f100000d760h',
#  '590m_val_pos_rw-006f100000d761B',
#  '590m_rw-neg-tr-upper-0-580',
#  '590m_val_pos_rw-006f100000dhmUv',
#  '590m_val_pos_rw-006f100000d7Q8j',
#  '590m_rw-neg-tr-lower-0-519',
#  '590m_rw-neg-tr-upper-0-434',
#  '590m_ug-neg-te-0-175',
#  '590m_train_pos_rw-006f100000d7ieS',
#  '590m_train_pos_rw-006f100000a86DY',
#  '590m_val_pos_rw-006f100000eekhP',
#  '590m_rw-neg-tr-lower-0-451',
#  '590m_rw-neg-tr-upper-0-463',
#  '590m_rw-neg-tr-lower-0-568',
#  '590m_ug-neg-te-0-37',
#  '590m_val_pos_rw-006f100000a86Hv',
#  '590m_val_pos_rw-006f100000dhpEm',
#  '590m_train_pos_rw-006f100000d7wul',
#  '590m_rw-neg-tr-lower-0-487',
#  '590m_ug-neg-te-0-60',
#  '590m_train_pos_rw-006f100000atGB5',
#  '590m_val_pos_rw-006f100000d7EQ9',
#  '590m_train_pos_rw-006f100000biK9r',
#  '590m_train_pos_rw-006f100000cPuua',
#  '590m_val_pos_rw-006f100000d6wGd',
#  '590m_ug-neg-te-0-212',
#  '590m_rw-neg-tr-lower-0-563',
#  '590m_val_pos_rw-006f100000d7ESA',
#  '590m_rw-neg-tr-upper-0-492',
#  '590m_rw-neg-tr-lower-0-546',
#  '590m_train_pos_rw-006f100000a86Gx',
#  '590m_train_pos_rw-006f100000d7GsI',
#  '590m_rw-neg-tr-lower-0-550',
#  '590m_rw-neg-tr-upper-0-529',
#  '590m_val_pos_rw-006f100000d6ksP',
#  '590m_rw-neg-tr-lower-0-445',
#  '590m_rw-neg-tr-upper-0-500',
#  '590m_val_pos_rw-006f100000d6wFb',
#  '590m_rw-neg-tr-lower-0-567',
#  '590m_rw-neg-tr-upper-0-533',
#  '590m_rw-neg-tr-lower-0-497',
#  '590m_train_pos_rw-006f100000ef7en',
#  '590m_val_pos_rw-006f100000d7ERl',
#  '590m_rw-neg-tr-lower-0-553',
#  '590m_val_pos_rw-006f100000eekgl',
#  '590m_rw-neg-tr-upper-0-551',
#  '590m_ug-neg-te-0-248',
#  '590m_rw-neg-tr-lower-0-455',
#  '590m_ug-neg-te-0-176',
#  '590m_rw-neg-tr-upper-0-516',
#  '590m_ug-neg-te-0-59',
#  '590m_rw-neg-tr-upper-0-486',
#  '590m_ug-neg-te-0-12',
#  '590m_train_pos_rw-006f100000a86E4',
#  '590m_ug-neg-te-0-142',
#  '590m_rw-neg-tr-upper-0-424',
#  '590m_rw-neg-tr-upper-0-415',
#  '590m_ug-neg-te-0-162',
#  '590m_rw-neg-tr-upper-0-518',
#  '590m_rw-neg-tr-upper-0-457',
#  '590m_train_pos_rw-006f100000eevNx',
#  '590m_train_pos_rw-006f100000d6mYL',
#  '590m_val_pos_rw-006f100000a86HY',
#  '590m_train_pos_rw-006f100000eekX2',
#  '590m_train_pos_rw-006f100000a86Da',
#  '590m_train_pos_rw-006f100000d7Q5C',
#  '590m_ug-neg-te-0-33',
#  '590m_ug-neg-te-0-138',
#  '590m_rw-neg-tr-lower-0-499',
#  '590m_val_pos_rw-006f100000eekhF',
#  '590m_rw-neg-tr-lower-0-508',
#  '590m_ug-neg-te-0-98',
#  '590m_rw-neg-tr-lower-0-571',
#  '590m_val_pos_rw-006f100000d7x5o',
#  '590m_train_pos_rw-006f100000asEzN',
#  '590m_val_pos_rw-006f100000d7678',
#  '590m_rw-neg-tr-upper-0-425',
#  '590m_rw-neg-tr-upper-0-408',
#  '590m_train_pos_rw-006f100000efHAR',
#  '590m_val_pos_rw-006f100000d7wvt',
#  '590m_val_pos_rw-006f100000d7bA7',
#  '590m_train_pos_rw-006f100000d7Q6K',
#  '590m_val_pos_rw-006f100000d7wvo',
#  '590m_train_pos_rw-006f100000d7Q5R',
#  '590m_val_pos_rw-006f100000d7ETN',
#  '590m_train_pos_rw-006f100000d7x5e',
#  '590m_ug-neg-te-0-144',
#  '590m_train_pos_rw-006f100000biK9w',
#  '590m_val_pos_rw-006f100000d7icg',
#  '590m_rw-neg-tr-upper-0-532',
#  '590m_rw-neg-tr-upper-0-437',
#  '590m_train_pos_rw-006f100000d1hPv',
#  '590m_val_pos_rw-006f100000eescb',
#  '590m_train_pos_rw-006f100000d7ETc',
#  '590m_train_pos_rw-006f100000a86Fz',
#  '590m_ug-neg-te-0-240',
#  '590m_val_pos_rw-006f100000d7icq',
#  '590m_ug-neg-te-0-27',
#  '590m_ug-neg-te-0-121',
#  '590m_train_pos_rw-006f100000d7ESP',
#  '590m_ug-neg-te-0-43',
#  '590m_rw-neg-tr-upper-0-585',
#  '590m_ug-neg-te-0-154',
#  '590m_train_pos_rw-006f100000eevMa',
#  '590m_train_pos_rw-006f100000d7x5A',
#  '590m_train_pos_rw-006f100000c5iL7',
#  '590m_train_pos_rw-006f100000a86E2',
#  '590m_rw-neg-tr-lower-0-524',
#  '590m_val_pos_rw-006f100000a86Dk',
#  '590m_ug-neg-te-0-229',
#  '590m_rw-neg-tr-lower-0-557',
#  '590m_val_pos_rw-006f100000d6wRu',
#  '590m_train_pos_rw-006f100000c5V5L',
#  '590m_rw-neg-tr-upper-0-491',
#  '590m_ug-neg-te-0-88',
#  '590m_rw-neg-tr-upper-0-432',
#  '590m_train_pos_rw-006f100000dhpCW',
#  '590m_train_pos_rw-006f100000d7ELA',
#  '590m_train_pos_rw-006f100000cMQ0C',
#  '590m_rw-neg-tr-upper-0-453',
#  '590m_val_pos_rw-006f100000d7cjc',
#  '590m_rw-neg-tr-lower-0-489',
#  '590m_train_pos_rw-006f100000d6wC3',
#  '590m_rw-neg-tr-upper-0-576',
#  '590m_val_pos_rw-006f100000d7603',
#  '590m_train_pos_rw-006f100000d7wug',
#  '590m_rw-neg-tr-upper-0-417',
#  '590m_val_pos_rw-006f100000d7ifG',
#  '590m_val_pos_rw-006f100000d6wRa',
#  '590m_rw-neg-tr-lower-0-441',
#  '590m_val_pos_rw-006f100000eekfx',
#  '590m_val_pos_rw-006f100000a86HT',
#  '590m_train_pos_rw-006f100000d6wBU',
#  '590m_ug-neg-te-0-113',
#  '590m_rw-neg-tr-lower-0-525',
#  '590m_rw-neg-tr-upper-0-556',
#  '590m_train_pos_rw-006f100000d6wBZ',
#  '590m_rw-neg-tr-upper-0-589',
#  '590m_train_pos_rw-006f100000a86HQ',
#  '590m_ug-neg-te-0-200',
#  '590m_train_pos_rw-006f100000efEeX',
#  '590m_val_pos_rw-006f100000d767S',
#  '590m_train_pos_rw-006f100000c5hhN',
#  '590m_val_pos_rw-006f100000d7cnF',
#  '590m_train_pos_rw-006f100000eekVL',
#  '590m_train_pos_rw-006f100000fHqCo',
#  '590m_rw-neg-tr-upper-0-507',
#  '590m_train_pos_rw-006f100000a86Gf',
#  '590m_rw-neg-tr-lower-0-475',
#  '590m_ug-neg-te-0-77',
#  '590m_val_pos_rw-006f100000d7bAR',
#  '590m_ug-neg-te-0-65',
#  '590m_ug-neg-te-0-73',
#  '590m_train_pos_rw-006f100000asF0V',
#  '590m_train_pos_rw-006f100000eekXv',
#  '590m_train_pos_rw-006f100000bMJz7',
#  '590m_train_pos_rw-006f100000c5ivZ',
#  '590m_train_pos_rw-006f100000d7x5y',
#  '590m_rw-neg-tr-upper-0-595',
#  '590m_train_pos_rw-006f100000efEfp',
#  '590m_rw-neg-tr-lower-0-452',
#  '590m_ug-neg-te-0-110',
#  '590m_train_pos_rw-006f100000efEl9',
#  '590m_train_pos_rw-006f100000d7wub',
#  '590m_val_pos_rw-006f100000d760m',
#  '590m_ug-neg-te-0-197',
#  '590m_rw-neg-tr-lower-0-521',
#  '590m_ug-neg-te-0-49',
#  '590m_train_pos_rw-006f100000d7wuv',
#  '590m_rw-neg-tr-upper-0-548',
#  '590m_rw-neg-tr-upper-0-452',
#  '590m_val_pos_rw-006f100000eekgC',
#  '590m_train_pos_rw-006f100000d761V',
#  '590m_val_pos_rw-006f100000eesse',
#  '590m_train_pos_rw-006f100000ZQRqC',
#  '590m_rw-neg-tr-lower-0-523',
#  '590m_rw-neg-tr-lower-0-425',
#  '590m_train_pos_rw-006f100000d7QQT',
#  '590m_val_pos_rw-006f100000a86D0',
#  '590m_train_pos_rw-006f100000d7QQO',
#  '590m_ug-neg-te-0-101',
#  '590m_rw-neg-tr-lower-0-476',
#  '590m_rw-neg-tr-upper-0-485',
#  '590m_ug-neg-te-0-79',
#  '590m_train_pos_rw-006f100000a86Hu',
#  '590m_train_pos_rw-006f100000bMK1d',
#  '590m_train_pos_rw-006f100000aWV5f',
#  '590m_rw-neg-tr-upper-0-445',
#  '590m_rw-neg-tr-lower-0-469',
#  '590m_ug-neg-te-0-134',
#  '590m_train_pos_rw-006f100000a86Dh',
#  '590m_train_pos_rw-006f100000d6kt3',
#  '590m_ug-neg-te-0-11',
#  '590m_ug-neg-te-0-223',
#  '590m_val_pos_rw-006f100000a86Cu',
#  '590m_train_pos_rw-006f100000a86E0',
#  '590m_ug-neg-te-0-209',
#  '590m_ug-neg-te-0-80',
#  '590m_train_pos_rw-006f100000d78Ou',
#  '590m_rw-neg-tr-upper-0-506',
#  '590m_val_pos_rw-006f100000eelZR',
#  '590m_rw-neg-tr-lower-0-482',
#  '590m_val_pos_rw-006f100000d7611',
#  '590m_train_pos_rw-006f100000eekXb',
#  '590m_ug-neg-te-0-184',
#  '590m_val_pos_rw-006f100000eekgb',
#  '590m_val_pos_rw-006f100000d75zK',
#  '590m_val_pos_rw-006f100000d8AoP',
#  '590m_ug-neg-te-0-126',
#  '590m_val_pos_rw-006f100000ZQRpv',
#  '590m_val_pos_rw-006f100000d766j',
#  '590m_ug-neg-te-0-234',
#  '590m_train_pos_rw-006f100000d6kr4',
#  '590m_train_pos_rw-006f100000d7EQE',
#  '590m_rw-neg-tr-lower-0-411',
#  '590m_rw-neg-tr-lower-0-584',
#  '590m_ug-neg-te-0-196',
#  '590m_rw-neg-tr-lower-0-485',
#  '590m_train_pos_rw-006f100000ary6h',
#  '590m_rw-neg-tr-upper-0-487',
#  '590m_train_pos_rw-006f100000eevNE',
#  '590m_train_pos_rw-006f100000d78OB',
#  '590m_ug-neg-te-0-224',
#  '590m_rw-neg-tr-lower-0-520',
#  '590m_rw-neg-tr-upper-0-419',
#  '590m_rw-neg-tr-upper-0-450',
#  '590m_val_pos_rw-006f100000d7jHP',
#  '590m_rw-neg-tr-upper-0-413',
#  '590m_rw-neg-tr-upper-0-581',
#  '590m_rw-neg-tr-lower-0-594',
#  '590m_ug-neg-te-0-149',
#  '590m_rw-neg-tr-lower-0-454',
#  '590m_train_pos_rw-006f100000a86EQ',
#  '590m_rw-neg-tr-lower-0-437',
#  '590m_val_pos_rw-006f100000eeqs4',
#  '590m_ug-neg-te-0-230',
#  '590m_train_pos_rw-006f100000eevLh',
#  '590m_ug-neg-te-0-140',
#  '590m_rw-neg-tr-upper-0-466',
#  '590m_val_pos_rw-006f100000d7EQO',
#  '590m_train_pos_rw-006f100000biK9A',
#  '590m_ug-neg-te-0-148',
#  '590m_train_pos_rw-006f100000c5V2g',
#  '590m_train_pos_rw-006f100000aATjC',
#  '590m_ug-neg-te-0-233',
#  '590m_val_pos_rw-006f100000d7bAH',
#  '590m_ug-neg-te-0-63',
#  '590m_ug-neg-te-0-107',
#  '590m_train_pos_rw-006f100000ZQRpz',
#  '590m_val_pos_rw-006f100000eelvw',
#  '590m_train_pos_rw-006f100000d7QSo',
#  '590m_train_pos_rw-006f100000a86G4',
#  '590m_rw-neg-tr-upper-0-436',
#  '590m_train_pos_rw-006f100000d7EMc',
#  '590m_val_pos_rw-006f100000ZQRqE',
#  '590m_train_pos_rw-006f100000d7kfS',
#  '590m_rw-neg-tr-upper-0-570',
#  '590m_rw-neg-tr-lower-0-502',
#  '590m_ug-neg-te-0-235',
#  '590m_rw-neg-tr-lower-0-530',
#  '590m_rw-neg-tr-upper-0-577',
#  '590m_train_pos_rw-006f100000a86Hx',
#  '590m_train_pos_rw-006f100000d7ETS',
#  '590m_ug-neg-te-0-207',
#  '590m_train_pos_rw-006f100000d7JCd',
#  '590m_train_pos_rw-006f100000d7ETX',
#  '590m_rw-neg-tr-upper-0-534',
#  '590m_val_pos_rw-006f100000d7hMW',
#  '590m_rw-neg-tr-upper-0-499',
#  '590m_rw-neg-tr-lower-0-531',
#  '590m_rw-neg-tr-lower-0-416',
#  '590m_train_pos_rw-006f100000d7jDX',
#  '590m_train_pos_rw-006f100000d762T',
#  '590m_train_pos_rw-006f100000d761G',
#  '590m_rw-neg-tr-lower-0-415',
#  '590m_ug-neg-te-0-32',
#  '590m_rw-neg-tr-lower-0-514',
#  '590m_ug-neg-te-0-35',
#  '590m_rw-neg-tr-lower-0-473',
#  '590m_rw-neg-tr-upper-0-423',
#  '590m_rw-neg-tr-lower-0-506',
#  '590m_rw-neg-tr-lower-0-478',
#  '590m_val_pos_rw-006f100000dhpDe',
#  '590m_train_pos_rw-006f100000a86Fy',
#  '590m_train_pos_rw-006f100000d7Q9c',
#  '590m_ug-neg-te-0-116',
#  '590m_rw-neg-tr-lower-0-435',
#  '590m_train_pos_rw-006f100000a86EU',
#  '590m_rw-neg-tr-lower-0-535',
#  '590m_ug-neg-te-0-89',
#  '590m_rw-neg-tr-lower-0-543',
#  '590m_rw-neg-tr-upper-0-426',
#  '590m_rw-neg-tr-upper-0-476',
#  '590m_val_pos_rw-006f100000eekg7',
#  '590m_train_pos_rw-006f100000dhyeV',
#  '590m_ug-neg-te-0-104',
#  '590m_val_pos_rw-006f100000a86I1',
#  '590m_rw-neg-tr-lower-0-577',
#  '590m_ug-neg-te-0-118',
#  '590m_ug-neg-te-0-91',
#  '590m_rw-neg-tr-upper-0-465',
#  '590m_rw-neg-tr-upper-0-474',
#  '590m_val_pos_rw-006f100000d7bAM',
#  '590m_train_pos_rw-006f100000bMJzq',
#  '590m_val_pos_rw-006f100000a86He',
#  '590m_rw-neg-tr-upper-0-418',
#  '590m_rw-neg-tr-lower-0-575',
#  '590m_ug-neg-te-0-191',
#  '590m_rw-neg-tr-upper-0-587',
#  '590m_val_pos_rw-006f100000d7jIN',
#  '590m_ug-neg-te-0-202',
#  '590m_val_pos_rw-006f100000eelkq',
#  '590m_val_pos_rw-006f100000d7QAG',
#  '590m_rw-neg-tr-lower-0-436',
#  '590m_rw-neg-tr-upper-0-459',
#  '590m_train_pos_rw-006f100000d7Q5v',
#  '590m_val_pos_rw-006f100000d7iau',
#  '590m_ug-neg-te-0-92',
#  '590m_val_pos_rw-006f100000eekgW',
#  '590m_rw-neg-tr-lower-0-492',
#  '590m_rw-neg-tr-upper-0-502',
#  '590m_rw-neg-tr-upper-0-584',
#  '590m_rw-neg-tr-upper-0-455',
#  '590m_ug-neg-te-0-105',
#  '590m_rw-neg-tr-lower-0-491',
#  '590m_ug-neg-te-0-45',
#  '590m_val_pos_rw-006f100000d7bAW',
#  '590m_ug-neg-te-0-23',
#  '590m_rw-neg-tr-lower-0-534',
#  '590m_train_pos_rw-006f100000bMJzC',
#  '590m_rw-neg-tr-upper-0-444',
#  '590m_train_pos_rw-006f100000efhn7',
#  '590m_ug-neg-te-0-183',
#  '590m_val_pos_rw-006f100000a86Hh',
#  '590m_ug-neg-te-0-71',
#  '590m_ug-neg-te-0-236',
#  '590m_ug-neg-te-0-213',
#  '590m_train_pos_rw-006f100000eekXH',
#  '590m_rw-neg-tr-upper-0-441',
#  '590m_train_pos_rw-006f100000a86Cx',
#  '590m_ug-neg-te-0-111',
#  '590m_ug-neg-te-0-13',
#  '590m_train_pos_rw-006f100000d7ktA',
#  '590m_train_pos_rw-006f100000d7wv5',
#  '590m_ug-neg-te-0-216',
#  '590m_val_pos_rw-006f100000ZQRkH',
#  '590m_train_pos_rw-006f100000d761Q',
#  '590m_rw-neg-tr-upper-0-462',
#  '590m_train_pos_rw-006f100000d7QTX',
#  '590m_ug-neg-te-0-232',
#  '590m_val_pos_rw-006f100000a86HW',
#  '590m_train_pos_rw-006f100000d7Q9X',
#  '590m_val_pos_rw-006f100000d7kl1',
#  '590m_train_pos_rw-006f100000biKA1',
#  '590m_ug-neg-te-0-72',
#  '590m_train_pos_rw-006f100000d7kjZ',
#  '590m_ug-neg-te-0-55',
#  '590m_val_pos_rw-006f100000a86Hm',
#  '590m_val_pos_rw-006f100000eevOR',
#  '590m_train_pos_rw-006f100000eekX7',
#  '590m_train_pos_rw-006f100000eeuxr',
#  '590m_val_pos_rw-006f100000eekgg',
#  '590m_rw-neg-tr-upper-0-565',
#  '590m_ug-neg-te-0-94',
#  '590m_train_pos_rw-006f100000d7wuq',
#  '590m_val_pos_rw-006f100000d8Ao5',
#  '590m_train_pos_rw-006f100000d7EZM',
#  '590m_ug-neg-te-0-133',
#  '590m_train_pos_rw-006f100000d7Q60',
#  '590m_val_pos_rw-006f100000a86Cy',
#  '590m_rw-neg-tr-upper-0-562',
#  '590m_train_pos_rw-006f100000d7JCi',
#  '590m_rw-neg-tr-upper-0-422',
#  '590m_ug-neg-te-0-122',
#  '590m_ug-neg-te-0-238',
#  '590m_val_pos_rw-006f100000d7kmY',
#  '590m_rw-neg-tr-upper-0-504',
#  '590m_rw-neg-tr-lower-0-552',
#  '590m_ug-neg-te-0-147',
#  '590m_rw-neg-tr-lower-0-516',
#  '590m_val_pos_rw-006f100000d6kpN',
#  '590m_train_pos_rw-006f100000bgzS3',
#  '590m_rw-neg-tr-lower-0-414',
#  '590m_train_pos_rw-006f100000a86Fa',
#  '590m_rw-neg-tr-lower-0-484',
#  '590m_ug-neg-te-0-127',
#  '590m_train_pos_rw-006f100000d6wQh',
#  '590m_train_pos_rw-006f100000ef7eT',
#  '590m_ug-neg-te-0-44',
#  '590m_ug-neg-te-0-158',
#  '590m_rw-neg-tr-lower-0-533',
#  '590m_train_pos_rw-006f100000d7Q4s',
#  '590m_ug-neg-te-0-90',
#  '590m_rw-neg-tr-lower-0-470',
#  '590m_train_pos_rw-006f100000ef7eO',
#  '590m_train_pos_rw-006f100000d7QSt',
#  '590m_ug-neg-te-0-54',
#  '590m_rw-neg-tr-upper-0-489',
#  '590m_rw-neg-tr-upper-0-509',
#  '590m_train_pos_rw-006f100000efEkk',
#  '590m_rw-neg-tr-upper-0-526',
#  '590m_val_pos_rw-006f100000eekcP',
#  '590m_train_pos_rw-006f100000d7ETr',
#  '590m_train_pos_rw-006f100000ZQRqA',
#  '590m_train_pos_rw-006f100000eekXq',
#  '590m_train_pos_rw-006f100000a86G5',
#  '590m_val_pos_rw-006f100000eevdq',
#  '590m_ug-neg-te-0-179',
#  '590m_ug-neg-te-0-141',
#  '590m_val_pos_rw-006f100000a86Hl',
#  '590m_rw-neg-tr-lower-0-420',
#  '590m_val_pos_rw-006f100000d7jI8',
#  '590m_train_pos_rw-006f100000a86DP',
#  '590m_train_pos_rw-006f100000a86I4',
#  '590m_train_pos_rw-006f100000a86Hi',
#  '590m_ug-neg-te-0-205',
#  '590m_train_pos_rw-006f100000d7iec',
#  '590m_rw-neg-tr-upper-0-558',
#  '590m_ug-neg-te-0-249',
#  '590m_val_pos_rw-006f100000eekgq',
#  '590m_val_pos_rw-006f100000d7jDc',
#  '590m_train_pos_rw-006f100000a86D4',
#  '590m_ug-neg-te-0-30',
#  '590m_ug-neg-te-0-215',
#  '590m_rw-neg-tr-upper-0-471',
#  '590m_train_pos_rw-006f100000a86Gu',
#  '590m_train_pos_rw-006f100000d7Q5H',
#  '590m_train_pos_rw-006f100000a86Hz',
#  '590m_rw-neg-tr-upper-0-470',
#  '590m_train_pos_rw-006f100000eekWs',
#  '590m_train_pos_rw-006f100000a86EM',
#  '590m_val_pos_rw-006f100000d7ib4',
#  '590m_rw-neg-tr-upper-0-579',
#  '590m_val_pos_rw-006f100000ZQRq8',
#  '590m_train_pos_rw-006f100000d762Y',
#  '590m_rw-neg-tr-upper-0-550',
#  '590m_rw-neg-tr-upper-0-438',
#  '590m_val_pos_rw-006f100000a86Hd',
#  '590m_rw-neg-tr-lower-0-582',
#  '590m_rw-neg-tr-upper-0-430',
#  '590m_train_pos_rw-006f100000eekXl',
#  '590m_train_pos_rw-006f100000d6wBt',
#  '590m_val_pos_rw-006f100000d7jHy',
#  '590m_ug-neg-te-0-204',
#  '590m_ug-neg-te-0-239',
#  '590m_rw-neg-tr-lower-0-423',
#  '590m_train_pos_rw-006f100000eevL3',
#  '590m_val_pos_rw-006f100000c5VQs',
#  '590m_val_pos_rw-006f100000eesiU',
#  '590m_rw-neg-tr-upper-0-517',
#  '590m_rw-neg-tr-lower-0-494',
#  '590m_rw-neg-tr-upper-0-567',
#  '590m_ug-neg-te-0-5',
#  '590m_val_pos_rw-006f100000eekdD',
#  '590m_rw-neg-tr-upper-0-497',
#  '590m_rw-neg-tr-lower-0-542',
#  '590m_ug-neg-te-0-120',
#  '590m_train_pos_rw-006f100000d7Gsr',
#  '590m_rw-neg-tr-lower-0-434',
#  '590m_rw-neg-tr-upper-0-543',
#  '590m_train_pos_rw-006f100000d7x5F',
#  '590m_val_pos_rw-006f100000a86D1',
#  '590m_val_pos_rw-006f100000d7ihb',
#  '590m_ug-neg-te-0-53',
#  '590m_rw-neg-tr-upper-0-451',
#  '590m_train_pos_rw-006f100000a86HN',
#  '590m_val_pos_rw-006f100000d7x5P',
#  '590m_val_pos_rw-006f100000a86DC',
#  '590m_ug-neg-te-0-97',
#  '590m_train_pos_rw-006f100000biKAa',
#  '590m_rw-neg-tr-lower-0-526',
#  '590m_val_pos_rw-006f100000d6wRk',
#  '590m_val_pos_rw-006f100000d760r',
#  '590m_train_pos_rw-006f100000a86GK',
#  '590m_rw-neg-tr-lower-0-448',
#  '590m_val_pos_rw-006f100000eewEc',
#  '590m_rw-neg-tr-lower-0-440',
#  '590m_train_pos_rw-006f100000d6wRQ',
#  '590m_train_pos_rw-006f100000dhpCR',
#  '590m_rw-neg-tr-lower-0-422',
#  '590m_rw-neg-tr-upper-0-540',
#  '590m_train_pos_rw-006f100000biK9K',
#  '590m_train_pos_rw-006f100000d7Q6F',
#  '590m_train_pos_rw-006f100000bMJys',
#  '590m_val_pos_rw-006f100000d767D',
#  '590m_rw-neg-tr-lower-0-464',
#  '590m_val_pos_rw-006f100000d7bAl',
#  '590m_val_pos_rw-006f100000eekg2',
#  '590m_train_pos_rw-006f100000ZQRpr',
#  '590m_ug-neg-te-0-214',
#  '590m_ug-neg-te-0-157',
#  '590m_ug-neg-te-0-66',
#  '590m_train_pos_rw-006f100000eekYF',
#  '590m_ug-neg-te-0-68',
#  '590m_ug-neg-te-0-36',
#  '590m_train_pos_rw-006f100000a7n8N',
#  '590m_rw-neg-tr-lower-0-556',
#  '590m_rw-neg-tr-upper-0-592',
#  '590m_val_pos_rw-006f100000eekgM',
#  '590m_rw-neg-tr-upper-0-481',
#  '590m_ug-neg-te-0-177',
#  '590m_ug-neg-te-0-15',
#  '590m_val_pos_rw-006f100000d7ibY',
#  '590m_val_pos_rw-006f100000a86I0',
#  '590m_train_pos_rw-006f100000ef7eY',
#  '590m_val_pos_rw-006f100000a86D9',
#  '590m_val_pos_rw-006f100000d766y',
#  '590m_val_pos_rw-006f100000eeqss',
#  '590m_rw-neg-tr-lower-0-504',
#  '590m_rw-neg-tr-upper-0-484',
#  '590m_train_pos_rw-006f100000a86Fi',
#  '590m_train_pos_rw-006f100000ZQRq2',
#  '590m_val_pos_rw-006f100000d767N',
#  '590m_rw-neg-tr-lower-0-564',
#  '590m_train_pos_rw-006f100000ef7jE',
#  '590m_val_pos_rw-006f100000d7wvA',
#  '590m_train_pos_rw-006f100000d6wRz',
#  '590m_rw-neg-tr-lower-0-505',
#  '590m_train_pos_rw-006f100000d7if6',
#  '590m_train_pos_rw-006f100000eekVz',
#  '590m_val_pos_rw-006f100000eelvm',
#  '590m_rw-neg-tr-lower-0-565',
#  '590m_ug-neg-te-0-206',
#  '590m_rw-neg-tr-upper-0-522',
#  '590m_train_pos_rw-006f100000atwPz',
#  '590m_ug-neg-te-0-172',
#  '590m_val_pos_rw-006f100000d7igs',
#  '590m_ug-neg-te-0-153',
#  '590m_ug-neg-te-0-178',
#  '590m_rw-neg-tr-lower-0-532',
#  '590m_ug-neg-te-0-211',
#  '590m_train_pos_rw-006f100000d1fUS',
#  '590m_rw-neg-tr-lower-0-573',
#  '590m_ug-neg-te-0-182',
#  '590m_train_pos_rw-006f100000d7QAB',
#  '590m_val_pos_rw-006f100000d7ETI',
#  '590m_rw-neg-tr-lower-0-443',
#  '590m_train_pos_rw-006f100000a86Gl',
#  '590m_train_pos_rw-006f100000d7Pqw',
#  '590m_rw-neg-tr-lower-0-419',
#  '590m_rw-neg-tr-lower-0-477',
#  '590m_ug-neg-te-0-114',
#  '590m_train_pos_rw-006f100000d7EMX',
#  '590m_ug-neg-te-0-171',
#  '590m_rw-neg-tr-upper-0-433',
#  '590m_rw-neg-tr-lower-0-547',
#  '590m_val_pos_rw-006f100000d7608',
#  '590m_val_pos_rw-006f100000eekhA',
#  '590m_rw-neg-tr-upper-0-493',
#  '590m_val_pos_rw-006f100000bgeFT',
#  '590m_train_pos_rw-006f100000d7ETD',
#  '590m_rw-neg-tr-lower-0-529',
#  '590m_rw-neg-tr-lower-0-590',
#  '590m_rw-neg-tr-upper-0-421',
#  '590m_val_pos_rw-006f100000d7jIS',
#  '590m_train_pos_rw-006f100000d6mYV',
#  '590m_val_pos_rw-006f100000d7icR',
#  '590m_val_pos_rw-006f100000d7EQx',
#  '590m_val_pos_rw-006f100000d760N',
#  '590m_rw-neg-tr-lower-0-438',
#  '590m_train_pos_rw-006f100000c5jCG',
#  '590m_train_pos_rw-006f100000a86De',
#  '590m_ug-neg-te-0-220',
#  '590m_rw-neg-tr-lower-0-518',
#  '590m_train_pos_rw-006f100000d7Q9I',
#  '590m_rw-neg-tr-lower-0-493',
#  '590m_rw-neg-tr-upper-0-571',
#  '590m_ug-neg-te-0-42',
#  '590m_rw-neg-tr-upper-0-597',
#  '590m_train_pos_rw-006f100000a86E9',
#  '590m_rw-neg-tr-upper-0-473',
#  '590m_ug-neg-te-0-62',
#  '590m_val_pos_rw-006f100000eesdP',
#  '590m_ug-neg-te-0-19',
#  '590m_rw-neg-tr-upper-0-520',
#  '590m_rw-neg-tr-upper-0-569',
#  '590m_val_pos_rw-006f100000a86Hq',
#  '590m_rw-neg-tr-upper-0-410',
#  '590m_train_pos_rw-006f100000a86E3',
#  '590m_train_pos_rw-006f100000d762O',
#  '590m_rw-neg-tr-upper-0-527',
#  '590m_train_pos_rw-006f100000a86DA',
#  '590m_ug-neg-te-0-81',
#  '590m_val_pos_rw-006f100000eessF',
#  '590m_rw-neg-tr-lower-0-407',
#  '590m_train_pos_rw-006f100000c5V2b',
#  '590m_rw-neg-tr-lower-0-596',
#  '590m_ug-neg-te-0-221',
#  '590m_train_pos_rw-006f100000a86EO',
#  '590m_rw-neg-tr-lower-0-587',
#  '590m_train_pos_rw-006f100000eevMu',
#  '590m_rw-neg-tr-upper-0-501',
#  '590m_train_pos_rw-006f100000a86G3',
#  '590m_ug-neg-te-0-86',
#  '590m_train_pos_rw-006f100000d7Q65',
#  '590m_train_pos_rw-006f100000eekYP',
#  '590m_val_pos_rw-006f100000eeqsY',
#  '590m_train_pos_rw-006f100000d7Q5M',
#  '590m_val_pos_rw-006f100000d7icM',
#  '590m_val_pos_rw-006f100000a86DI',
#  '590m_ug-neg-te-0-3',
#  '590m_rw-neg-tr-upper-0-479',
#  '590m_ug-neg-te-0-39',
#  '590m_train_pos_rw-006f100000dhyea',
#  '590m_rw-neg-tr-upper-0-555',
#  '590m_ug-neg-te-0-195',
#  '590m_ug-neg-te-0-169',
#  '590m_ug-neg-te-0-198',
#  '590m_train_pos_rw-006f100000d7Pr6',
#  '590m_rw-neg-tr-lower-0-421',
#  '590m_rw-neg-tr-upper-0-541',
#  '590m_train_pos_rw-006f100000a86DW',
#  '590m_val_pos_rw-006f100000eekhe',
#  '590m_val_pos_rw-006f100000eessK',
#  '590m_train_pos_rw-006f100000biKAu',
#  '590m_ug-neg-te-0-6',
#  '590m_rw-neg-tr-lower-0-591',
#  '590m_rw-neg-tr-lower-0-449',
#  '590m_val_pos_rw-006f100000a86Hj',
#  '590m_rw-neg-tr-upper-0-596',
#  '590m_rw-neg-tr-upper-0-568',
#  '590m_rw-neg-tr-upper-0-412',
#  '590m_val_pos_rw-006f100000eekgv',
#  '590m_train_pos_rw-006f100000d7ibs',
#  '590m_rw-neg-tr-lower-0-412',
#  '590m_rw-neg-tr-lower-0-467',
#  '590m_rw-neg-tr-lower-0-549',
#  '590m_ug-neg-te-0-34',
#  '590m_rw-neg-tr-upper-0-488',
#  '590m_train_pos_rw-006f100000a86D2',
#  '590m_train_pos_rw-006f100000eevOb',
#  '590m_ug-neg-te-0-168',
#  '590m_rw-neg-tr-upper-0-583',
#  '590m_rw-neg-tr-upper-0-525',
#  '590m_rw-neg-tr-lower-0-426',
#  '590m_rw-neg-tr-upper-0-411',
#  '590m_ug-neg-te-0-22',
#  '590m_rw-neg-tr-lower-0-433',
#  '590m_val_pos_rw-006f100000eekh5',
#  '590m_val_pos_rw-006f100000d7jID',
#  '590m_val_pos_rw-006f100000d766Z',
#  '590m_rw-neg-tr-lower-0-517',
#  '590m_train_pos_rw-006f100000a86EP',
#  '590m_rw-neg-tr-lower-0-578',
#  '590m_train_pos_rw-006f100000eeuzs',
#  '590m_ug-neg-te-0-87',
#  '590m_val_pos_rw-006f100000a86HS',
#  '590m_rw-neg-tr-lower-0-462',
#  '590m_rw-neg-tr-upper-0-536',
#  '590m_train_pos_rw-006f100000a86GU',
#  '590m_rw-neg-tr-upper-0-483',
#  '590m_rw-neg-tr-upper-0-554',
#  '590m_rw-neg-tr-lower-0-498',
#  '590m_ug-neg-te-0-161',
#  '590m_train_pos_rw-006f100000d7Pqr',
#  '590m_ug-neg-te-0-245',
#  '590m_train_pos_rw-006f100000d6wCN',
#  '590m_val_pos_rw-006f100000d767I',
#  '590m_train_pos_rw-006f100000biKAL',
#  '590m_val_pos_rw-006f100000d7idt',
#  '590m_train_pos_rw-006f100000d7jMt',
#  '590m_ug-neg-te-0-188',
#  '590m_train_pos_rw-006f100000efHCI',
#  '590m_train_pos_rw-006f100000a86EC',
#  '590m_train_pos_rw-006f100000bh0JK',
#  '590m_ug-neg-te-0-174',
#  '590m_rw-neg-tr-upper-0-547',
#  '590m_val_pos_rw-006f100000a86ES',
#  '590m_train_pos_rw-006f100000bKz7z',
#  '590m_train_pos_rw-006f100000a86E1',
#  '590m_train_pos_rw-006f100000cPpL8',
#  '590m_val_pos_rw-006f100000d7Q98',
#  '590m_ug-neg-te-0-117',
#  '590m_train_pos_rw-006f100000d7QQY',
#  '590m_ug-neg-te-0-115',
#  '590m_train_pos_rw-006f100000a86G6',
#  '590m_ug-neg-te-0-48',
#  '590m_ug-neg-te-0-193',
#  '590m_train_pos_rw-006f100000d6mY6',
#  '590m_train_pos_rw-006f100000d7QQn',
#  '590m_ug-neg-te-0-125',
#  '590m_train_pos_rw-006f100000d6wCD',
#  '590m_rw-neg-tr-lower-0-586',
#  '590m_rw-neg-tr-upper-0-546',
#  '590m_train_pos_rw-006f100000bNTvY',
#  '590m_rw-neg-tr-upper-0-443',
#  '590m_train_pos_rw-006f100000a86DB',
#  '590m_rw-neg-tr-lower-0-447',
#  '590m_rw-neg-tr-lower-0-458',
#  '590m_rw-neg-tr-upper-0-538',
#  '590m_rw-neg-tr-lower-0-583',
#  '590m_rw-neg-tr-lower-0-465',
#  '590m_rw-neg-tr-upper-0-490',
#  '590m_ug-neg-te-0-146',
#  '590m_train_pos_rw-006f100000d7wve',
#  '590m_ug-neg-te-0-189',
#  '590m_train_pos_rw-006f100000d7ETm',
#  '590m_train_pos_rw-006f100000d7hE8',
#  '590m_train_pos_rw-006f100000a86D5',
#  '590m_val_pos_rw-006f100000d7bAC',
#  '590m_rw-neg-tr-upper-0-578',
#  '590m_train_pos_rw-006f100000eevLX',
#  '590m_ug-neg-te-0-75',
#  '590m_train_pos_rw-006f100000eekYt',
#  '590m_rw-neg-tr-upper-0-494',
#  '590m_rw-neg-tr-lower-0-522',
#  '590m_ug-neg-te-0-226',
#  '590m_val_pos_rw-006f100000eekhZ',
#  '590m_rw-neg-tr-upper-0-496',
#  '590m_ug-neg-te-0-18',
#  '590m_val_pos_rw-006f100000d7EQd',
#  '590m_rw-neg-tr-upper-0-590',
#  '590m_val_pos_rw-006f100000d7icb',
#  '590m_ug-neg-te-0-217',
#  '590m_val_pos_rw-006f100000a86Hr',
#  '590m_ug-neg-te-0-57',
#  '590m_rw-neg-tr-upper-0-521',
#  '590m_rw-neg-tr-upper-0-449',
#  '590m_rw-neg-tr-upper-0-409',
#  '590m_rw-neg-tr-lower-0-592',
#  '590m_rw-neg-tr-upper-0-593',
#  '590m_train_pos_rw-006f100000d6wC8',
#  '590m_rw-neg-tr-lower-0-561',
#  '590m_rw-neg-tr-upper-0-469',
#  '590m_ug-neg-te-0-99',
#  '590m_val_pos_rw-006f100000eeqqS',
#  '590m_train_pos_rw-006f100000efEfz',
#  '590m_train_pos_rw-006f100000eesiy',
#  '590m_ug-neg-te-0-242',
#  '590m_ug-neg-te-0-1',
#  '590m_train_pos_rw-006f100000eekXC',
#  '590m_ug-neg-te-0-135',
#  '590m_train_pos_rw-006f100000d6wQm',
#  '590m_ug-neg-te-0-109',
#  '590m_train_pos_rw-006f100000d7wv0',
#  '590m_val_pos_rw-006f100000d6wHb',
#  '590m_ug-neg-te-0-201',
#  '590m_rw-neg-tr-lower-0-424',
#  '590m_ug-neg-te-0-47',
#  '590m_rw-neg-tr-upper-0-515',
#  '590m_train_pos_rw-006f100000d7Q9S',
#  '590m_train_pos_rw-006f100000bgzEa',
#  '590m_val_pos_rw-006f100000d7ww3',
#  '590m_rw-neg-tr-lower-0-466',
#  '590m_train_pos_rw-006f100000bMK0j',
#  '590m_ug-neg-te-0-96',
#  '590m_train_pos_rw-006f100000d7iQL',
#  '590m_ug-neg-te-0-21',
#  '590m_ug-neg-te-0-24',
#  '590m_val_pos_rw-006f100000d7ER7',
#  '590m_rw-neg-tr-lower-0-540',
#  '590m_ug-neg-te-0-159',
#  '590m_val_pos_rw-006f100000d7kk8',
#  '590m_ug-neg-te-0-46',
#  ...}

# %% [markdown]
# # Extract images from dataset

# %% [markdown]
# ## 320m

# %%
i = 0

# %%
area_length = 2 * 320 - 50
tile_size = 320
print("Start downloading")
while i < len(lon_lat_list):
    print("i in [{};{}]".format(i, i + 100))
    for n in range(i, min(i + 100, len(lon_lat_list))):
        # desc += " {}".format(n)
        lon  = lon_lat_list[n][0]
        lat = lon_lat_list[n][1]
        geometry = ee.Geometry.Rectangle(get_square_area(lon, lat, area_length))
        visualized = dataset.clip(geometry).visualize(**rgbVis)
        fpath = "{}m_{}_{}".format(area_length, lon_lat_list[n][2], n)
        task = ee.batch.Export.image.toDrive(
            image=visualized,
            # task name to be shown in the Tasks tab
            description=fpath,
            # filename to be saved in the Google Drive
            fileNamePrefix=fpath,
            folder="{}_b2p_rgb_large_{}_{}_neg".format(
                vname, area_length, tile_size),
            scale=10, # the spatial resolution of the image
            region=geometry,
            maxPixels=1e13
        )
        task.start()
    i += 100
    print("Sleep...")
    time.sleep(10*60)
# Out:
# Start downloading
# i in [0;100]
# Sleep...
# i in [100;200]
# Sleep...
# i in [200;300]
# Sleep...
# i in [300;400]
# Sleep...
# i in [400;500]
# Sleep...
# i in [500;600]
# Sleep...
# i in [600;700]
# Sleep...
# i in [700;800]
# Sleep...
# i in [800;900]
# Sleep...
# i in [900;1000]
# Sleep...
# i in [1000;1100]
# Sleep...
# i in [1100;1200]
# Sleep...
# i in [1200;1300]
# Sleep...
# i in [1300;1400]
# Sleep...
# i in [1400;1500]
# Sleep...
# i in [1500;1600]
# Sleep...
# i in [1600;1700]
# Sleep...
# i in [1700;1800]
# Sleep...

# %% [markdown]
# ## 600

# %%
i = 0

# %%
area_length = 2 * 600 - 50
tile_size = 600
print("Start downloading")
while i < len(lon_lat_list):
    print("i in [{};{}]".format(i, i + 100))
    for n in range(i, min(i + 100, len(lon_lat_list))):
        # desc += " {}".format(n)
        lon  = lon_lat_list[n][0]
        lat = lon_lat_list[n][1]
        geometry = ee.Geometry.Rectangle(get_square_area(lon, lat, area_length))
        visualized = dataset.clip(geometry).visualize(**rgbVis)
        fpath = "{}m_{}_{}".format(area_length, lon_lat_list[n][2], n)
        task = ee.batch.Export.image.toDrive(
            image=visualized,x
            # task name to be shown in the Tasks tab
            description=fpath,
            # filename to be saved in the Google Drive
            fileNamePrefix=fpath,
            folder="{}_b2p_rgb_large_{}_{}_neg".format(
                vname, area_length, tile_size),
            scale=10, # the spatial resolution of the image
            region=geometry,
            maxPixels=1e13
        )
        task.start()
    i += 100
    print("Sleep...")
    time.sleep(10*80)
# Out:
# Start downloading
# i in [0;100]
# Sleep...
# i in [100;200]
# Sleep...
# i in [200;300]
# Sleep...
# i in [300;400]
# Sleep...
# i in [400;500]
# Sleep...
# i in [500;600]
# Sleep...
# i in [600;700]
# Sleep...
# i in [700;800]
# Sleep...
# i in [800;900]
# Sleep...
# i in [900;1000]
# Sleep...
# i in [1000;1100]
# Sleep...
# i in [1100;1200]
# Sleep...
# i in [1200;1300]
# Sleep...
# i in [1300;1400]
# Sleep...
# i in [1400;1500]
# Sleep...
# i in [1500;1600]
# Sleep...
# i in [1600;1700]
# Sleep...
# i in [1700;1800]
# Sleep...

# %% [markdown]
# ## 1200

# %%
i = 0

# %%
area_length = 2 * 1200 - 50
tile_size = 1200
print("Start downloading")
while i < len(lon_lat_list):
    print("i in [{};{}]".format(i, i + 100))
    for n in range(i, min(i + 100, len(lon_lat_list))):
        # desc += " {}".format(n)
        lon  = lon_lat_list[n][0]
        lat = lon_lat_list[n][1]
        geometry = ee.Geometry.Rectangle(get_square_area(lon, lat, area_length))
        visualized = dataset.clip(geometry).visualize(**rgbVis)
        fpath = "{}m_{}_{}".format(area_length, lon_lat_list[n][2], n)
        task = ee.batch.Export.image.toDrive(
            image=visualized,
            # task name to be shown in the Tasks tab
            description=fpath,
            # filename to be saved in the Google Drive
            fileNamePrefix=fpath,
            folder="{}_b2p_rgb_large_{}_{}_neg".format(
                vname, area_length, tile_size),
            scale=10, # the spatial resolution of the image
            region=geometry,
            maxPixels=1e13
        )
        task.start()
    i += 100
    print("Sleep...")
    time.sleep(10*80)
# Out:
# Start downloading
# i in [0;100]
# Sleep...
# i in [100;200]
# Sleep...
# i in [200;300]
# Sleep...
# i in [300;400]
# Sleep...
# i in [400;500]
# Sleep...
# i in [500;600]
# Sleep...
# i in [600;700]
# Sleep...
# i in [700;800]
# Sleep...
# i in [800;900]
# Sleep...
# i in [900;1000]
# Sleep...
# i in [1000;1100]
# Sleep...
# i in [1100;1200]
# Sleep...
# i in [1200;1300]
# Sleep...
# i in [1300;1400]
# Sleep...
# i in [1400;1500]
# Sleep...
# i in [1500;1600]
# Sleep...
# i in [1600;1700]
# Sleep...
# i in [1700;1800]
# Sleep...
