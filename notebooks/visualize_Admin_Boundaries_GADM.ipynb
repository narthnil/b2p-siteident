# %%
import geopandas as gpd

# %%
# Download single gpkg of whole world from
# https://gadm.org/download_world.html
geodb = gpd.read_file("../data/gadm36.gpkg")

# %%
# Get all country name
geodb.head()
# Out:
#       UID GID_0  ID_0       NAME_0    GID_1  ID_1      NAME_1 VARNAME_1  \
# 0  183022   AFG   1.0  Afghanistan  AFG.1_1   1.0  Badakhshan  Badahšan
# 1  182550   AFG   1.0  Afghanistan  AFG.1_1   1.0  Badakhshan  Badahšan
# 2  182994   AFG   1.0  Afghanistan  AFG.1_1   1.0  Badakhshan  Badahšan
# 3  183088   AFG   1.0  Afghanistan  AFG.1_1   1.0  Badakhshan  Badahšan
# 4  183159   AFG   1.0  Afghanistan  AFG.1_1   1.0  Badakhshan  Badahšan
#
#   NL_NAME_1 HASC_1  ... GID_5 ID_5 NAME_5  CC_5 TYPE_5 ENGTYPE_5 REGION  \
# 0      None  AF.BD  ...  None  NaN   None  None   None      None   None
# 1      None  AF.BD  ...  None  NaN   None  None   None      None   None
# 2      None  AF.BD  ...  None  NaN   None  None   None      None   None
# 3      None  AF.BD  ...  None  NaN   None  None   None      None   None
# 4      None  AF.BD  ...  None  NaN   None  None   None      None   None
#
#    VARREGION zone                                           geometry
# ...

# %%
geodb[ geodb['NAME_1'] == "California"].unary_union
